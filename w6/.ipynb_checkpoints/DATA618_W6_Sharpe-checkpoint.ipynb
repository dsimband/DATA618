# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from pandas_datareader import data as pdr
from datetime import datetime, date, timedelta

import yfinance as yfin
yfin.pdr_override()

import matplotlib.pyplot as plt
import seaborn as sns

#from var import VaR

pd.set_option('display.float_format', lambda x: f'{x:,.4f}')

# %% [markdown]
# # Assignment
# Familiarity with several pricing models and how to apply them to a portfolio. Now calculate the VWAP, Sharpe and Alpha for your portfolio from the start of the semester  to the date of you calculations. Your calculation results and the VaR calculations that you performed last week are the main content of the Portfolio Review presentation that is next week's subject and assignment. -- Remember Presentation is Important

# %% [markdown]
# # Variables

# %%
start_date = datetime(2022, 1, 1)
end_date = datetime.now()
alpha = 0.05
period = '20y'

# %% [markdown]
# # Functions

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Load Variables

# %%
var_lst = ['^TNX']
data = pdr.get_data_yahoo(var_lst, period=period)['Close']
rf_rate = round((data.mean() / 100),4)
rf_rate
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 0.029

# %% [markdown]
# ## Load Portfolio

# %%
folio_df = pd.read_csv('https://raw.githubusercontent.com/dsimband/DATA618/main/w5/data/DATA618_Portfolio.csv', 
                 dtype={
                    'ID': 'int',
                    'Price': 'float',
                    'Shares': 'float',
                    'Value': 'float', 
                 })


folio_df = folio_df[folio_df['Shares'] > 0]
folio_df = folio_df.groupby(['Ticker','BondName','Class'])[['Shares','Value']].sum()
folio_df.reset_index(inplace=True)
#folio_df['Morningstar_Category'].fillna('Other', inplace=True)

#folio_df = folio_df[4:]

portfolio_total = folio_df['Value'].sum()
folio_df['port_percent'] = folio_df['Value'] / portfolio_total

folio_df.head()
# Out:
#     Ticker                                 BondName                    Class  \
# 0    ALTVX     AB Municipal Income National Advisor  Interest Rate Sensitive
# 1    BLUEX         AMG Veritas Global Real Return I   Economically Sensitive
# 2    BPLSX  Boston Partners Long/Short Equity Instl   Economically Sensitive
# 3  C_A_S_H                                     Cash                     Cash
# 4     DFAR           Dimensional US Real Estate ETF   Economically Sensitive
#
#           Shares      Value  port_percent
# 0   106,383.0000 1,000.0000        0.0119
# 1    14,201.0000   500.0000        0.0060
# 2    49,967.0000   750.0000        0.0090
# 3 4,469,000.0000 4,469.0000        0.0534
# 4   108,468.0000 2,250.0000        0.0269

# %%
folio_df.groupby(['Class'])[['Value']].sum()
# Out:
#                               Value
# Class
# Cash                     4,469.0000
# Economically Sensitive  50,250.0000
# Interest Rate Sensitive 29,000.0000

# %%
initial_investment = folio_df['Value'].sum() * 1000
initial_investment
# Out:
# 83719000.0

# %% [markdown]
# ## Load Pricing Time Series

# %%
# ticker symbols
ticker_lst = list(folio_df['Ticker'])
print('ticker #:', len(ticker_lst))


# portfolio weights
weight_lst = (folio_df['port_percent'].values)
print('price #:', len(weight_lst))


#Download closing prices
#price_df = pdr.get_data_yahoo(ticker_lst, start=start_date, end=end_date)['Close']
price_df = pdr.get_data_yahoo(ticker_lst, period=period)['Close']

price_df['C_A_S_H'] = 1
print('price_df #:', len(price_df.columns))

#From the closing prices, calculate periodic returns
return_df = price_df.pct_change()
print('return_df #:', len(return_df.columns))
# Out:
# ticker #: 35
# price #: 35
# [*********************100%%**********************]  35 of 35 completed
# 1 Failed download:
# ['C_A_S_H']: Exception('%ticker%: No data found, symbol may be delisted')
# price_df #: 35
# return_df #: 35

# %%
print('ticker #:', len(ticker_lst))
# Out:
# ticker #: 35

# %%
price_df
# Out:
#             ALTVX   BLUEX   BPLSX  C_A_S_H    DFAR    FREL    FSMD   GARIX  \
# Date
# 2003-10-06    NaN 22.2700 14.0500        1     NaN     NaN     NaN     NaN
# 2003-10-07    NaN 22.3500 14.0700        1     NaN     NaN     NaN     NaN
# 2003-10-08    NaN 22.2600 14.0800        1     NaN     NaN     NaN     NaN
# 2003-10-09    NaN 22.4300 14.0500        1     NaN     NaN     NaN     NaN
# 2003-10-10    NaN 22.5000 14.0500        1     NaN     NaN     NaN     NaN
# ...           ...     ...     ...      ...     ...     ...     ...     ...
# 2023-09-29 9.1700 33.9900 14.8200        1 19.5200 22.7500 32.2700 19.4700
# 2023-10-02 9.1400 33.8400 14.7800        1 19.1800 22.3300 31.8820 19.4700
# 2023-10-03 9.1100 33.6300 14.7000        1 18.8100 21.8900 31.4580 19.2900
# 2023-10-04 9.1100 33.8200 14.6900        1 19.0300 22.1300 31.6800 19.4000
# 2023-10-05    NaN     NaN     NaN        1 19.1300 22.2800 31.6663     NaN
#
#              GCHDX  ICBFX  ...  SWRSX      VBR   VFIUX   VGCAX   VICSX  \
# Date                       ...
# 2003-10-06     NaN    NaN  ...    NaN      NaN 11.5500     NaN     NaN
# 2003-10-07     NaN    NaN  ...    NaN      NaN 11.5000     NaN     NaN
# 2003-10-08     NaN    NaN  ...    NaN      NaN 11.5100     NaN     NaN
# 2003-10-09     NaN    NaN  ...    NaN      NaN 11.4800     NaN     NaN
# 2003-10-10     NaN    NaN  ...    NaN      NaN 11.5000     NaN     NaN
# ...            ...    ...  ...    ...      ...     ...     ...     ...
# 2023-09-29 10.5600 5.8900  ... 9.8900 159.4900  9.5900 17.9500 20.4400
# 2023-10-02 10.5400 5.8400  ... 9.8200 156.9400  9.5400 17.8600 20.2800
# 2023-10-03 10.4500 5.7900  ... 9.7600 154.4600  9.4900 17.7400 20.1100
# 2023-10-04 10.5300 5.8200  ... 9.8000 155.0600  9.5300 17.8200 20.2200
# 2023-10-05     NaN    NaN  ...    NaN 155.0200     NaN     NaN     NaN
#
#               VIGI     VNQ       VO    VONG    VTEB
# Date
# 2003-10-06     NaN     NaN      NaN     NaN     NaN
# 2003-10-07     NaN     NaN      NaN     NaN     NaN
# 2003-10-08     NaN     NaN      NaN     NaN     NaN
# 2003-10-09     NaN     NaN      NaN     NaN     NaN
# 2003-10-10     NaN     NaN      NaN     NaN     NaN
# ...            ...     ...      ...     ...     ...
# 2023-09-29 71.3300 75.6600 208.2400 68.4400 48.1000
# 2023-10-02 70.5500 74.2700 205.8000 69.0300 47.7100
# 2023-10-03 69.8800 72.8200 202.9400 67.8000 47.5700
# 2023-10-04 70.3800 73.7100 204.5500 68.6900 47.7300
# 2023-10-05 70.9300 74.1200 204.0600 68.7200 47.7100
#
# [5035 rows x 35 columns]

# %%
return_df = return_df[1:]
return_df
# Out:
#              ALTVX   BLUEX   BPLSX  C_A_S_H    DFAR    FREL    FSMD   GARIX  \
# Date
# 2003-10-07     NaN  0.0036  0.0014   0.0000     NaN     NaN     NaN     NaN
# 2003-10-08     NaN -0.0040  0.0007   0.0000     NaN     NaN     NaN     NaN
# 2003-10-09     NaN  0.0076 -0.0021   0.0000     NaN     NaN     NaN     NaN
# 2003-10-10     NaN  0.0031  0.0000   0.0000     NaN     NaN     NaN     NaN
# 2003-10-13     NaN  0.0071  0.0014   0.0000     NaN     NaN     NaN     NaN
# ...            ...     ...     ...      ...     ...     ...     ...     ...
# 2023-09-29  0.0022 -0.0038 -0.0074   0.0000  0.0021  0.0026 -0.0051  0.0000
# 2023-10-02 -0.0033 -0.0044 -0.0027   0.0000 -0.0174 -0.0185 -0.0120  0.0000
# 2023-10-03 -0.0033 -0.0062 -0.0054   0.0000 -0.0193 -0.0197 -0.0133 -0.0092
# 2023-10-04  0.0000  0.0056 -0.0007   0.0000  0.0117  0.0110  0.0071  0.0057
# 2023-10-05  0.0000  0.0000  0.0000   0.0000  0.0053  0.0068 -0.0004  0.0000
#
#              GCHDX   ICBFX  ...   SWRSX     VBR   VFIUX   VGCAX   VICSX  \
# Date                        ...
# 2003-10-07     NaN     NaN  ...     NaN     NaN -0.0043     NaN     NaN
# 2003-10-08     NaN     NaN  ...     NaN     NaN  0.0009     NaN     NaN
# 2003-10-09     NaN     NaN  ...     NaN     NaN -0.0026     NaN     NaN
# 2003-10-10     NaN     NaN  ...     NaN     NaN  0.0017     NaN     NaN
# 2003-10-13     NaN     NaN  ...     NaN     NaN  0.0000     NaN     NaN
# ...            ...     ...  ...     ...     ...     ...     ...     ...
# 2023-09-29  0.0000  0.0000  ... -0.0110 -0.0036  0.0000 -0.0105 -0.0034
# 2023-10-02 -0.0019 -0.0085  ... -0.0071 -0.0160 -0.0052 -0.0050 -0.0078
# 2023-10-03 -0.0085 -0.0086  ... -0.0061 -0.0158 -0.0052 -0.0067 -0.0084
# 2023-10-04  0.0077  0.0052  ...  0.0041  0.0039  0.0042  0.0045  0.0055
# 2023-10-05  0.0000  0.0000  ...  0.0000 -0.0003  0.0000  0.0000  0.0000
#
#               VIGI     VNQ      VO    VONG    VTEB
# Date
# 2003-10-07     NaN     NaN     NaN     NaN     NaN
# 2003-10-08     NaN     NaN     NaN     NaN     NaN
# 2003-10-09     NaN     NaN     NaN     NaN     NaN
# 2003-10-10     NaN     NaN     NaN     NaN     NaN
# 2003-10-13     NaN     NaN     NaN     NaN     NaN
# ...            ...     ...     ...     ...     ...
# 2023-09-29 -0.0039  0.0029 -0.0030 -0.0006  0.0015
# 2023-10-02 -0.0109 -0.0184 -0.0117  0.0086 -0.0081
# 2023-10-03 -0.0095 -0.0195 -0.0139 -0.0178 -0.0029
# 2023-10-04  0.0072  0.0122  0.0079  0.0131  0.0034
# 2023-10-05  0.0078  0.0056 -0.0024  0.0004 -0.0004
#
# [5034 rows x 35 columns]

# %% [markdown]
# ## Analytics

# %% [markdown]
# return_df.corr()

# %%
plt.figure(figsize=(20,10))
mask = np.zeros_like(price_df.corr())
mask[np.triu_indices_from(mask)] = True
sns.set_style("white")
_p = sns.heatmap(price_df.corr().round(2), 
                 annot=True, mask=mask, 
                 cmap="plasma", annot_kws={"size": 10})

# %% [markdown]
# # VaR Calculation

# %% [markdown]
# #Generate Var-Cov matrix
# cov_matrix = return_df.cov()
# cov_matrix

# %% [markdown]
# #Calculate mean returns for each stock
# avg_ret_df = return_df.mean()
#
# #Calculate mean returns for portfolio overall,
# #using mean, using dot product formula to
# #normalize against investment weights
# port_mean = avg_ret_df.dot(weight_lst)
#
# #Calculate portfolio standard deviation
# port_stdev = np.sqrt(weight_lst.T.dot(cov_matrix).dot(weight_lst))
#
# #Calculate mean of given investment
# mean_investment = (1+port_mean) * initial_investment
#
# #Calculate standard deviation of given investmnet
# stdev_investment = initial_investment * port_stdev

# %% [markdown]
# ## Calculate the inverse of the normal cumulative distribution (PPF)

# %% [markdown]
# #Using SciPy ppf method to generate values for the inverse cumulative distribution function to a normal distribution
# #https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html
# from scipy.stats import norm
# cutoff1 = norm.ppf(alpha, mean_investment, stdev_investment)

# %% [markdown]
# #Finally, we can calculate the VaR at our confidence interval
# var_1d1 = initial_investment - cutoff1
# var_1d1

# %% [markdown]
# ## Value at risk over n-day time period

# %% [markdown]
# # Calculate n Day VaR
# var_array = []
# num_days = int(30)
# for x in range(1, num_days+1):
#     var_array.append(np.round(var_1d1 * np.sqrt(x),2))
#     print(str(x) + " day VaR @ 95% confidence: " + str(np.round(var_1d1 * np.sqrt(x),2)))
#
# # Build plot
# plt.xlabel("Day #")
# plt.ylabel("Max portfolio loss (USD)")
# plt.title("Max portfolio loss (VaR) over 15-day period")
# plt.plot(var_array, "r")

# %% [markdown]
# # Sharpe Calculation

# %%
port_ret_weighted= return_df.mul(weight_lst, axis=1)
port_ret_weighted
# Out:
#              ALTVX   BLUEX   BPLSX  C_A_S_H    DFAR    FREL    FSMD   GARIX  \
# Date
# 2003-10-07     NaN  0.0000  0.0000   0.0000     NaN     NaN     NaN     NaN
# 2003-10-08     NaN -0.0000  0.0000   0.0000     NaN     NaN     NaN     NaN
# 2003-10-09     NaN  0.0000 -0.0000   0.0000     NaN     NaN     NaN     NaN
# 2003-10-10     NaN  0.0000  0.0000   0.0000     NaN     NaN     NaN     NaN
# 2003-10-13     NaN  0.0000  0.0000   0.0000     NaN     NaN     NaN     NaN
# ...            ...     ...     ...      ...     ...     ...     ...     ...
# 2023-09-29  0.0000 -0.0000 -0.0001   0.0000  0.0001  0.0001 -0.0002  0.0000
# 2023-10-02 -0.0000 -0.0000 -0.0000   0.0000 -0.0005 -0.0006 -0.0006  0.0000
# 2023-10-03 -0.0000 -0.0000 -0.0000   0.0000 -0.0005 -0.0007 -0.0006 -0.0001
# 2023-10-04  0.0000  0.0000 -0.0000   0.0000  0.0003  0.0004  0.0003  0.0000
# 2023-10-05  0.0000  0.0000  0.0000   0.0000  0.0001  0.0002 -0.0000  0.0000
#
#              GCHDX   ICBFX  ...   SWRSX     VBR   VFIUX   VGCAX   VICSX  \
# Date                        ...
# 2003-10-07     NaN     NaN  ...     NaN     NaN -0.0003     NaN     NaN
# 2003-10-08     NaN     NaN  ...     NaN     NaN  0.0001     NaN     NaN
# 2003-10-09     NaN     NaN  ...     NaN     NaN -0.0002     NaN     NaN
# 2003-10-10     NaN     NaN  ...     NaN     NaN  0.0001     NaN     NaN
# 2003-10-13     NaN     NaN  ...     NaN     NaN  0.0000     NaN     NaN
# ...            ...     ...  ...     ...     ...     ...     ...     ...
# 2023-09-29  0.0000  0.0000  ... -0.0008 -0.0000  0.0000 -0.0001 -0.0001
# 2023-10-02 -0.0000 -0.0001  ... -0.0005 -0.0002 -0.0003 -0.0001 -0.0002
# 2023-10-03 -0.0001 -0.0001  ... -0.0004 -0.0002 -0.0003 -0.0001 -0.0002
# 2023-10-04  0.0000  0.0001  ...  0.0003  0.0000  0.0003  0.0001  0.0001
# 2023-10-05  0.0000  0.0000  ...  0.0000 -0.0000  0.0000  0.0000  0.0000
#
#               VIGI     VNQ      VO    VONG    VTEB
# Date
# 2003-10-07     NaN     NaN     NaN     NaN     NaN
# 2003-10-08     NaN     NaN     NaN     NaN     NaN
# 2003-10-09     NaN     NaN     NaN     NaN     NaN
# 2003-10-10     NaN     NaN     NaN     NaN     NaN
# 2003-10-13     NaN     NaN     NaN     NaN     NaN
# ...            ...     ...     ...     ...     ...
# 2023-09-29 -0.0001  0.0001 -0.0001 -0.0000  0.0000
# 2023-10-02 -0.0004 -0.0007 -0.0003  0.0003 -0.0001
# 2023-10-03 -0.0003 -0.0008 -0.0003 -0.0006 -0.0000
# 2023-10-04  0.0003  0.0005  0.0002  0.0005  0.0000
# 2023-10-05  0.0003  0.0002 -0.0001  0.0000 -0.0000
#
# [5034 rows x 35 columns]

# %%
return_df['Portfolio']= port_ret_weighted.sum(axis=1).dropna()
return_df
# Out:
#              ALTVX   BLUEX   BPLSX  C_A_S_H    DFAR    FREL    FSMD   GARIX  \
# Date
# 2003-10-07     NaN  0.0036  0.0014   0.0000     NaN     NaN     NaN     NaN
# 2003-10-08     NaN -0.0040  0.0007   0.0000     NaN     NaN     NaN     NaN
# 2003-10-09     NaN  0.0076 -0.0021   0.0000     NaN     NaN     NaN     NaN
# 2003-10-10     NaN  0.0031  0.0000   0.0000     NaN     NaN     NaN     NaN
# 2003-10-13     NaN  0.0071  0.0014   0.0000     NaN     NaN     NaN     NaN
# ...            ...     ...     ...      ...     ...     ...     ...     ...
# 2023-09-29  0.0022 -0.0038 -0.0074   0.0000  0.0021  0.0026 -0.0051  0.0000
# 2023-10-02 -0.0033 -0.0044 -0.0027   0.0000 -0.0174 -0.0185 -0.0120  0.0000
# 2023-10-03 -0.0033 -0.0062 -0.0054   0.0000 -0.0193 -0.0197 -0.0133 -0.0092
# 2023-10-04  0.0000  0.0056 -0.0007   0.0000  0.0117  0.0110  0.0071  0.0057
# 2023-10-05  0.0000  0.0000  0.0000   0.0000  0.0053  0.0068 -0.0004  0.0000
#
#              GCHDX   ICBFX  ...     VBR   VFIUX   VGCAX   VICSX    VIGI  \
# Date                        ...
# 2003-10-07     NaN     NaN  ...     NaN -0.0043     NaN     NaN     NaN
# 2003-10-08     NaN     NaN  ...     NaN  0.0009     NaN     NaN     NaN
# 2003-10-09     NaN     NaN  ...     NaN -0.0026     NaN     NaN     NaN
# 2003-10-10     NaN     NaN  ...     NaN  0.0017     NaN     NaN     NaN
# 2003-10-13     NaN     NaN  ...     NaN  0.0000     NaN     NaN     NaN
# ...            ...     ...  ...     ...     ...     ...     ...     ...
# 2023-09-29  0.0000  0.0000  ... -0.0036  0.0000 -0.0105 -0.0034 -0.0039
# 2023-10-02 -0.0019 -0.0085  ... -0.0160 -0.0052 -0.0050 -0.0078 -0.0109
# 2023-10-03 -0.0085 -0.0086  ... -0.0158 -0.0052 -0.0067 -0.0084 -0.0095
# 2023-10-04  0.0077  0.0052  ...  0.0039  0.0042  0.0045  0.0055  0.0072
# 2023-10-05  0.0000  0.0000  ... -0.0003  0.0000  0.0000  0.0000  0.0078
#
#                VNQ      VO    VONG    VTEB  Portfolio
# Date
# 2003-10-07     NaN     NaN     NaN     NaN    -0.0001
# 2003-10-08     NaN     NaN     NaN     NaN    -0.0001
# 2003-10-09     NaN     NaN     NaN     NaN    -0.0000
# 2003-10-10     NaN     NaN     NaN     NaN     0.0001
# 2003-10-13     NaN     NaN     NaN     NaN     0.0004
# ...            ...     ...     ...     ...        ...
# 2023-09-29  0.0029 -0.0030 -0.0006  0.0015    -0.0014
# 2023-10-02 -0.0184 -0.0117  0.0086 -0.0081    -0.0089
# 2023-10-03 -0.0195 -0.0139 -0.0178 -0.0029    -0.0107
# 2023-10-04  0.0122  0.0079  0.0131  0.0034     0.0047
# 2023-10-05  0.0056 -0.0024  0.0004 -0.0004     0.0015
#
# [5034 rows x 36 columns]

# %%
tickers='NIFTYBEES.NS'
NIFTY50 = pdr.get_data_yahoo(tickers=tickers, period=period)
return_df['Benchmark']= NIFTY50['Close']
return_df['Benchmark']= return_df['Benchmark'].pct_change(1) #.dropna()
#return_df= return_df.dropna()
return_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#              ALTVX   BLUEX   BPLSX  C_A_S_H    DFAR    FREL    FSMD   GARIX  \
# Date
# 2003-10-07     NaN  0.0036  0.0014   0.0000     NaN     NaN     NaN     NaN
# 2003-10-08     NaN -0.0040  0.0007   0.0000     NaN     NaN     NaN     NaN
# 2003-10-09     NaN  0.0076 -0.0021   0.0000     NaN     NaN     NaN     NaN
# 2003-10-10     NaN  0.0031  0.0000   0.0000     NaN     NaN     NaN     NaN
# 2003-10-13     NaN  0.0071  0.0014   0.0000     NaN     NaN     NaN     NaN
# ...            ...     ...     ...      ...     ...     ...     ...     ...
# 2023-09-29  0.0022 -0.0038 -0.0074   0.0000  0.0021  0.0026 -0.0051  0.0000
# 2023-10-02 -0.0033 -0.0044 -0.0027   0.0000 -0.0174 -0.0185 -0.0120  0.0000
# 2023-10-03 -0.0033 -0.0062 -0.0054   0.0000 -0.0193 -0.0197 -0.0133 -0.0092
# 2023-10-04  0.0000  0.0056 -0.0007   0.0000  0.0117  0.0110  0.0071  0.0057
# 2023-10-05  0.0000  0.0000  0.0000   0.0000  0.0053  0.0068 -0.0004  0.0000
#
#              GCHDX   ICBFX  ...   VFIUX   VGCAX   VICSX    VIGI     VNQ  \
# Date                        ...
# 2003-10-07     NaN     NaN  ... -0.0043     NaN     NaN     NaN     NaN
# 2003-10-08     NaN     NaN  ...  0.0009     NaN     NaN     NaN     NaN
# 2003-10-09     NaN     NaN  ... -0.0026     NaN     NaN     NaN     NaN
# 2003-10-10     NaN     NaN  ...  0.0017     NaN     NaN     NaN     NaN
# 2003-10-13     NaN     NaN  ...  0.0000     NaN     NaN     NaN     NaN
# ...            ...     ...  ...     ...     ...     ...     ...     ...
# 2023-09-29  0.0000  0.0000  ...  0.0000 -0.0105 -0.0034 -0.0039  0.0029
# 2023-10-02 -0.0019 -0.0085  ... -0.0052 -0.0050 -0.0078 -0.0109 -0.0184
# 2023-10-03 -0.0085 -0.0086  ... -0.0052 -0.0067 -0.0084 -0.0095 -0.0195
# 2023-10-04  0.0077  0.0052  ...  0.0042  0.0045  0.0055  0.0072  0.0122
# 2023-10-05  0.0000  0.0000  ...  0.0000  0.0000  0.0000  0.0078  0.0056
#
#                 VO    VONG    VTEB  Portfolio  Benchmark
# Date
# 2003-10-07     NaN     NaN     NaN    -0.0001        NaN
# 2003-10-08     NaN     NaN     NaN    -0.0001        NaN
# 2003-10-09     NaN     NaN     NaN    -0.0000        NaN
# 2003-10-10     NaN     NaN     NaN     0.0001        NaN
# 2003-10-13     NaN     NaN     NaN     0.0004        NaN
# ...            ...     ...     ...        ...        ...
# 2023-09-29 -0.0030 -0.0006  0.0015    -0.0014     0.0045
# 2023-10-02 -0.0117  0.0086 -0.0081    -0.0089     0.0000
# 2023-10-03 -0.0139 -0.0178 -0.0029    -0.0107    -0.0054
# 2023-10-04  0.0079  0.0131  0.0034     0.0047    -0.0054
# 2023-10-05 -0.0024  0.0004 -0.0004     0.0015     0.0053
#
# [5034 rows x 37 columns]

# %%
cum_ret_port = ((1 + return_df['Portfolio']).cumprod()-1)
cum_ret_port.plot(label='Cumulative Returns of the Portfolio' ,figsize=(19,8),title='Cumulative Returns')
_=plt.xlabel('Date' )
_=plt.ylabel('Portfolio Cumulative Return' )

# %%
port_bench = pd.concat([return_df['Portfolio' ],return_df['Benchmark' ]],axis=1 ).dropna()
port_bench.columns=['Portfolio',' Benchmark' ]
correlation=port_bench.corr()
correlation
# Out:
#             Portfolio   Benchmark
# Portfolio      1.0000      0.0161
#  Benchmark     0.0161      1.0000

# %%
return_df['RF Rate']=0.0469
return_df
# Out:
#              ALTVX   BLUEX   BPLSX  C_A_S_H    DFAR    FREL    FSMD   GARIX  \
# Date
# 2003-10-07     NaN  0.0036  0.0014   0.0000     NaN     NaN     NaN     NaN
# 2003-10-08     NaN -0.0040  0.0007   0.0000     NaN     NaN     NaN     NaN
# 2003-10-09     NaN  0.0076 -0.0021   0.0000     NaN     NaN     NaN     NaN
# 2003-10-10     NaN  0.0031  0.0000   0.0000     NaN     NaN     NaN     NaN
# 2003-10-13     NaN  0.0071  0.0014   0.0000     NaN     NaN     NaN     NaN
# ...            ...     ...     ...      ...     ...     ...     ...     ...
# 2023-09-29  0.0022 -0.0038 -0.0074   0.0000  0.0021  0.0026 -0.0051  0.0000
# 2023-10-02 -0.0033 -0.0044 -0.0027   0.0000 -0.0174 -0.0185 -0.0120  0.0000
# 2023-10-03 -0.0033 -0.0062 -0.0054   0.0000 -0.0193 -0.0197 -0.0133 -0.0092
# 2023-10-04  0.0000  0.0056 -0.0007   0.0000  0.0117  0.0110  0.0071  0.0057
# 2023-10-05  0.0000  0.0000  0.0000   0.0000  0.0053  0.0068 -0.0004  0.0000
#
#              GCHDX   ICBFX  ...   VGCAX   VICSX    VIGI     VNQ      VO  \
# Date                        ...
# 2003-10-07     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2003-10-08     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2003-10-09     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2003-10-10     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2003-10-13     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# ...            ...     ...  ...     ...     ...     ...     ...     ...
# 2023-09-29  0.0000  0.0000  ... -0.0105 -0.0034 -0.0039  0.0029 -0.0030
# 2023-10-02 -0.0019 -0.0085  ... -0.0050 -0.0078 -0.0109 -0.0184 -0.0117
# 2023-10-03 -0.0085 -0.0086  ... -0.0067 -0.0084 -0.0095 -0.0195 -0.0139
# 2023-10-04  0.0077  0.0052  ...  0.0045  0.0055  0.0072  0.0122  0.0079
# 2023-10-05  0.0000  0.0000  ...  0.0000  0.0000  0.0078  0.0056 -0.0024
#
#               VONG    VTEB  Portfolio  Benchmark  RF Rate
# Date
# 2003-10-07     NaN     NaN    -0.0001        NaN   0.0469
# 2003-10-08     NaN     NaN    -0.0001        NaN   0.0469
# 2003-10-09     NaN     NaN    -0.0000        NaN   0.0469
# 2003-10-10     NaN     NaN     0.0001        NaN   0.0469
# 2003-10-13     NaN     NaN     0.0004        NaN   0.0469
# ...            ...     ...        ...        ...      ...
# 2023-09-29 -0.0006  0.0015    -0.0014     0.0045   0.0469
# 2023-10-02  0.0086 -0.0081    -0.0089     0.0000   0.0469
# 2023-10-03 -0.0178 -0.0029    -0.0107    -0.0054   0.0469
# 2023-10-04  0.0131  0.0034     0.0047    -0.0054   0.0469
# 2023-10-05  0.0004 -0.0004     0.0015     0.0053   0.0469
#
# [5034 rows x 38 columns]

# %%
return_df['excess_b' ]= return_df['Benchmark' ] - return_df['RF Rate' ]

# %%
sharpe_ratio=((return_df['Portfolio' ].mean() - return_df['RF Rate'].mean()))/return_df['Portfolio' ].std()
sharpe_ratio
# Out:
# -10.745548903265137
