# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from pandas_datareader import data as pdr
from datetime import datetime, date, timedelta

import yfinance as yfin
yfin.pdr_override()

import matplotlib.pyplot as plt
import seaborn as sns

#from var import VaR

pd.set_option('display.float_format', lambda x: f'{x:,.6f}')

# %% [markdown]
# # Assignment
# Familiarity with several pricing models and how to apply them to a portfolio. Now calculate the VWAP, Sharpe and Alpha for your portfolio from the start of the semester  to the date of you calculations. Your calculation results and the VaR calculations that you performed last week are the main content of the Portfolio Review presentation that is next week's subject and assignment.
#
# -- Remember Presentation is Important
#
#
# <b> Sharpe Ratio </b>
#
# Sharpe ratio is a measure for calculating risk-adjusted return. It is the ratio of the excess expected return of investment (over risk-free rate) per unit of volatility or standard deviation.

# %% [markdown]
# # Variables

# %%
period = '5y'

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Load Variables

# %%
#var_lst = ['^SPX']
#var_lst = ['^TNX']
var_lst = ['TNX']
data = pdr.get_data_yahoo(var_lst, period=period)['Close']
rf_df = data.pct_change()
rf_rate = rf_df.mean()
rf_rate
# Out:
# [*********************100%%**********************]  1 of 1 completed
# -0.016533451391655823

# %% [markdown]
# ## Load Portfolio

# %% [markdown]
# folio_df = pd.read_csv('https://raw.githubusercontent.com/dsimband/DATA618/main/w6/data/DATA618_Portfolio.csv',
#                  dtype={
#                     'ID': 'int',
#                     'Price': 'float',
#                     'Shares': 'float',
#                     'Value': 'float',
#                  })

# %% [markdown]
# folio_df = pd.read_csv('https://raw.githubusercontent.com/dsimband/DATA618/main/w15/data/DATA618_Portfolio_Full.csv',
#                  parse_dates =['Date'],
#                  dtype={
#                     'ID': 'int',
#                     'Value': 'float',
#                  })

# %%
folio_df = pd.read_csv('https://raw.githubusercontent.com/dsimband/DATA618/main/w15/data/DATA618_Portfolio_Rebalance_v2.csv', 
                 parse_dates=['Date'],
                 dtype={
                    'ID': 'int',
                    'Price': 'float',
                    'Shares': 'float',
                    'Value': 'float',
                 })

folio_df = folio_df[folio_df['Shares'] > 0]
folio_df = folio_df.groupby(['Ticker','BondName','Class','Sub_Class'])[['Shares','Value']].sum()
folio_df.reset_index(inplace=True)

# calculate portfilio percentage
portfolio_total = folio_df['Value'].sum()
folio_df['port_percent'] = folio_df['Value'] / portfolio_total

# Class Portfolios
folio_econ_df = folio_df[folio_df['Class'] == 'Economically Sensitive']
folio_int_df = folio_df[folio_df['Class'] == 'Interest Rate Sensitive']

folio_df
# Out:
#      Ticker                                  BondName  \
# 0     ALTVX      AB Municipal Income National Advisor
# 1      ARKK                        ARK Innovation ETF
# 2     BLUEX          AMG Veritas Global Real Return I
# 3     BPLSX   Boston Partners Long/Short Equity Instl
# 4   C_A_S_H                                      Cash
# 5      DFAR            Dimensional US Real Estate ETF
# 6      EXAS                       Exact Sciences Corp
# 7      FREL             Fidelity MSCI Real Estate ETF
# 8      FSMD        Fidelity Small-Mid Multifactor ETF
# 9     GARIX      Gotham Absolute Return Institutional
# 10    GCHDX          Gotham Hedged Core Institutional
# 11    ICBFX                 Invesco Corporate Bond R6
# 12    IGMWX                        Voya GNMA Income W
# 13     IGRO     iShares International Dividend Gr ETF
# 14     IMCB           iShares Morningstar Mid-Cap ETF
# 15     ISCF    iShares MSCI Intl Small-Cap Mltfct ETF
# 16      IVV                  iShares Core S&P 500 ETF
# 17     JPEM  JPMorgan Diversified Return EMkts Eq ETF
# 18     JPRE                JPMorgan Realty Income ETF
# 19     MEAR   iShares Short Maturity Municipal Bd ETF
# 20     MMIN           IQ MacKay Municipal Insured ETF
# 21     MMIT      IQ MacKay Municipal Intermediate ETF
# 22     NVTA                              Invitae Corp
# 23     PATH                        UiPath Inc Class A
# 24      PEX    ProShares Global Listed Private Equity
# 25    PFRAX    PIMCO International Bond (USD-Hdg) Adm
# 26    PSAIX  PIMCO Global Advantage Strategy Bd Instl
# 27     SCHD            Schwab US Dividend Equity ETF™
# 28    SNDPX                  AB Diversified Municipal
# 29    SWRSX   Schwab Treasury Infl Protected Secs Idx
# 30     TWLO                        Twilio Inc Class A
# 31      VBR              Vanguard Small-Cap Value ETF
# 32    VFIUX         Vanguard Interm-Term Treasury Adm
# 33    VGCAX       Vanguard Global Credit Bond Admiral
# 34    VICSX  Vanguard Interm-Term Corp Bd Idx Admiral
# 35     VIGI              Vanguard Intl Div Apprec ETF
# 36      VNQ                  Vanguard Real Estate ETF
# 37       VO                      Vanguard Mid-Cap ETF
# 38     VONG          Vanguard Russell 1000 Growth ETF
# 39     VTEB              Vanguard Tax-Exempt Bond ETF
#
#                       Class                          Sub_Class  \
# 0   Interest Rate Sensitive  Very-High-Quality Municipal Bonds
# 1    Economically Sensitive                      U.S. Equities
# 2    Economically Sensitive                Long/Short Equities
# 3    Economically Sensitive                Long/Short Equities
# 4                      Cash                               Cash
# 5    Economically Sensitive              Publicly Traded REITs
# 6    Economically Sensitive                      U.S. Equities
# 7    Economically Sensitive              Publicly Traded REITs
# 8    Economically Sensitive                      U.S. Equities
# 9    Economically Sensitive                Long/Short Equities
# 10   Economically Sensitive                Long/Short Equities
# 11  Interest Rate Sensitive  Very-High-Quality Corporate Bonds
# 12  Interest Rate Sensitive              U.S. Government Bonds
# 13   Economically Sensitive             International Equities
# 14   Economically Sensitive                      U.S. Equities
# 15   Economically Sensitive             International Equities
# 16   Economically Sensitive                      U.S. Equities
# 17   Economically Sensitive           Emerging Market Equities
# 18   Economically Sensitive              Publicly Traded REITs
# 19  Interest Rate Sensitive  Very-High-Quality Municipal Bonds
# 20  Interest Rate Sensitive  Very-High-Quality Municipal Bonds
# 21  Interest Rate Sensitive  Very-High-Quality Municipal Bonds
# 22   Economically Sensitive                      U.S. Equities
# 23   Economically Sensitive                      U.S. Equities
# 24   Economically Sensitive                     Private Equity
# 25  Interest Rate Sensitive  Very-High-Quality Corporate Bonds
# 26  Interest Rate Sensitive  Very-High-Quality Corporate Bonds
# 27   Economically Sensitive                      U.S. Equities
# 28  Interest Rate Sensitive  Very-High-Quality Municipal Bonds
# 29  Interest Rate Sensitive              U.S. Government Bonds
# 30   Economically Sensitive                      U.S. Equities
# 31   Economically Sensitive                      U.S. Equities
# 32  Interest Rate Sensitive              U.S. Government Bonds
# 33  Interest Rate Sensitive  Very-High-Quality Corporate Bonds
# 34  Interest Rate Sensitive  Very-High-Quality Corporate Bonds
# 35   Economically Sensitive             International Equities
# 36   Economically Sensitive              Publicly Traded REITs
# 37   Economically Sensitive                      U.S. Equities
# 38   Economically Sensitive                      U.S. Equities
# 39  Interest Rate Sensitive  Very-High-Quality Municipal Bonds
#
#              Shares        Value  port_percent
# 0    106,383.000000 1,000.000000      0.011570
# 1     26,476.000000 1,000.000000      0.011570
# 2     14,201.000000   500.000000      0.005785
# 3     49,967.000000   750.000000      0.008677
# 4  3,182,856.000000 4,183.000000      0.048396
# 5    108,467.000000 2,250.000000      0.026032
# 6      7,660.000000   500.000000      0.005785
# 7    115,479.000000 2,800.000000      0.032395
# 8     89,079.000000 4,000.000000      0.046279
# 9     25,278.000000   500.000000      0.005785
# 10    46,211.000000   500.000000      0.005785
# 11   166,389.000000 1,000.000000      0.011570
# 12   763,889.000000 5,500.000000      0.063633
# 13    32,610.000000 2,000.000000      0.023139
# 14    47,619.000000 4,000.000000      0.046279
# 15    98,007.000000 3,000.000000      0.034709
# 16     8,912.000000 4,000.000000      0.046279
# 17    78,561.000000 4,000.000000      0.046279
# 18    60,695.000000 2,500.000000      0.028924
# 19    20,060.000000 1,000.000000      0.011570
# 20    42,553.000000 1,000.000000      0.011570
# 21    41,771.000000 1,000.000000      0.011570
# 22   814,332.000000   500.000000      0.005785
# 23    32,489.000000   500.000000      0.005785
# 24   150,754.000000 4,200.000000      0.048593
# 25   105,820.000000 1,000.000000      0.011570
# 26   103,413.000000 1,000.000000      0.011570
# 27    41,027.000000 3,000.000000      0.034709
# 28    73,529.000000 1,000.000000      0.011570
# 29   592,300.000000 6,000.000000      0.069418
# 30     8,996.000000   500.000000      0.005785
# 31     6,120.000000 1,000.000000      0.011570
# 32   566,426.000000 5,500.000000      0.063633
# 33    54,437.000000 1,000.000000      0.011570
# 34    95,923.000000 2,000.000000      0.023139
# 35    40,481.000000 3,000.000000      0.034709
# 36    40,221.000000 3,250.000000      0.037601
# 37     9,234.000000 2,000.000000      0.023139
# 38    41,501.000000 3,000.000000      0.034709
# 39    20,333.000000 1,000.000000      0.011570

# %%
folio_df.groupby(['Class'])[['Value']].sum()
# Out:
#                                 Value
# Class
# Cash                     4,183.000000
# Economically Sensitive  53,250.000000
# Interest Rate Sensitive 29,000.000000

# %%
initial_investment = folio_df['Value'].sum() * 1000
initial_investment
# Out:
# 86433000.0

# %% [markdown]
# # Portfolio

# %% [markdown]
# ## Load Pricing Time Series

# %%
# ticker symbols
ticker_lst = list(folio_df['Ticker'])
print('ticker #:', len(ticker_lst))


# portfolio weights
weight_lst = (folio_df['port_percent'].values)
print('price #:', len(weight_lst))


#Download closing prices
price_df = pdr.get_data_yahoo(ticker_lst, period=period)['Close']

price_df['C_A_S_H'] = 1
print('price_df #:', price_df.shape)

#From the closing prices, calculate periodic returns
return_df = price_df.pct_change()
print('return_df #:', len(return_df.columns))
# Out:
# ticker #: 40
# price #: 40
# [*********************100%%**********************]  40 of 40 completed
# 1 Failed download:
# ['C_A_S_H']: Exception('%ticker%: No data found, symbol may be delisted')
# price_df #: (1259, 40)
# return_df #: 40

# %%
plt.figure(figsize=(20,10))
mask = np.zeros_like(price_df.corr())
mask[np.triu_indices_from(mask)] = True
sns.set_style("white")
_p = sns.heatmap(price_df.corr().round(2), 
                 annot=True, mask=mask, 
                 cmap="plasma", annot_kws={"size": 10})

# %% [markdown]
# ## Portfolio Returns

# %%
port_ret_weighted= return_df.mul(weight_lst, axis=1)
print('port_ret_weighted #:', port_ret_weighted.shape)

return_df['Portfolio'] = port_ret_weighted.sum(axis=1)
print('return_df #:', return_df.shape)
# Out:
# port_ret_weighted #: (1259, 40)
# return_df #: (1259, 41)

# %%
tickers='^DJA'

DJA = pdr.get_data_yahoo(tickers=tickers, period=period)
return_df['Benchmark']= DJA['Close']
return_df['Benchmark']= return_df['Benchmark'].pct_change(1) #.dropna()

print('return_df #:', return_df.shape)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# return_df #: (1259, 42)

# %%
cum_ret_port = ((1 + return_df[['Portfolio','Benchmark']]).cumprod()-1)
cum_ret_port.plot(label='Cumulative Returns of the Portfolio' ,figsize=(14,8),title='Cumulative Returns (vs ^DJA)')
_=plt.xlabel('Date' )
_=plt.ylabel('Portfolio Cumulative Return' )

# %%
port_bench = pd.concat([return_df['Portfolio' ],return_df['Benchmark' ]],axis=1 ).dropna()
port_bench.columns=['Portfolio',' Benchmark' ]
correlation=port_bench.corr()
correlation
# Out:
#             Portfolio   Benchmark
# Portfolio    1.000000    0.911458
#  Benchmark   0.911458    1.000000

# %% [markdown]
# ## Sharpe Ratio

# %%
return_df['RF Rate']= rf_rate

sharpe_ratio=((return_df['Portfolio'].mean() - return_df['RF Rate'].mean()))/return_df['Portfolio' ].std()
sh = round(sharpe_ratio,4)
print(f"Sharpe Ratio: {sh:.7f} (50% {sh*0.5:.7f})")

avg = return_df['Portfolio'].mean() * 100
print(f"Portfolio Return Mean: {avg:.7f}")

std = return_df['Portfolio' ].std()
print(f"Portfolio Return Standard Deviation: {std:.7f}")
# Out:
# Sharpe Ratio: 2.1269000 (50% 1.0634500)
# Portfolio Return Mean: 0.0144363
# Portfolio Return Standard Deviation: 0.0078415

# %% [markdown]
# # Economically Sensitive

# %% [markdown]
# ## Load Pricing Time Series

# %%
# ticker symbols
ticker_lst = list(folio_econ_df['Ticker'])
print('ticker #:', len(ticker_lst))


# portfolio weights
weight_lst = (folio_econ_df['port_percent'].values)
print('price #:', len(weight_lst))

#Download closing prices
#price_df = pdr.get_data_yahoo(ticker_lst, start=start_date, end=end_date)['Close']
price_econ_df = pdr.get_data_yahoo(ticker_lst, period=period)['Close']

#From the closing prices, calculate periodic returns
return_econ_df = price_econ_df.pct_change()
return_econ_df = return_econ_df[1:]
print('return_df #:', return_econ_df.shape)
# Out:
# ticker #: 25
# price #: 25
# [*********************100%%**********************]  25 of 25 completed
# return_df #: (1258, 25)

# %%
plt.figure(figsize=(20,10))
mask = np.zeros_like(price_econ_df.corr())
mask[np.triu_indices_from(mask)] = True
sns.set_style("white")
_p = sns.heatmap(price_econ_df.corr().round(2), 
                 annot=True, mask=mask, 
                 cmap="plasma", annot_kws={"size": 10})

# %% [markdown]
# ## Portfolio Returns

# %%
port_ret_weighted= return_econ_df.mul(weight_lst, axis=1)
print('port_ret_weighted #:', port_ret_weighted.shape)

#return_econ_df['Portfolio'] = port_ret_weighted.sum(axis=1).dropna()
return_econ_df['Portfolio'] = port_ret_weighted.sum(axis=1)
print('return_econ_df #:', return_econ_df.shape)
# Out:
# port_ret_weighted #: (1258, 25)
# return_econ_df #: (1258, 26)

# %%
tickers='^DJA'
#tickers = 'FHNFX'
DJA = pdr.get_data_yahoo(tickers=tickers, period=period)
return_econ_df['Benchmark']= DJA['Close']
return_econ_df['Benchmark']= return_econ_df['Benchmark'].pct_change(1) #.dropna()
#return_df= return_df.dropna()
print('return_econ_df #:', return_econ_df.shape)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# return_econ_df #: (1258, 27)

# %%
cum_ret_port = ((1 + return_econ_df[['Portfolio','Benchmark']]).cumprod()-1)
cum_ret_port.plot(label='Cumulative Returns of the Portfolio' ,figsize=(19,8),title='Cumulative Returns - Economically Sensitive (vs ^DJA)')
_=plt.xlabel('Date' )
_=plt.ylabel('Portfolio Cumulative Return' )

# %%
port_bench = pd.concat([return_econ_df['Portfolio' ],return_econ_df['Benchmark' ]],axis=1 ).dropna()
port_bench.columns=['Portfolio',' Benchmark' ]
correlation=port_bench.corr()
correlation
# Out:
#             Portfolio   Benchmark
# Portfolio    1.000000    0.926622
#  Benchmark   0.926622    1.000000

# %% [markdown]
# ## Sharpe Ratio

# %%
return_econ_df['RF Rate']= rf_rate

sharpe_ratio=((return_econ_df['Portfolio'].mean() - return_econ_df['RF Rate'].mean()))/return_econ_df['Portfolio' ].std()
sh = round(sharpe_ratio,4)
print(f"Sharpe Ratio: {sh:.7f} (50% {sh*0.5:.7f})")

avg = return_econ_df['Portfolio'].mean() * 100
print(f"Portfolio Return Mean: {avg:.7f}")

std = return_econ_df['Portfolio' ].std()
print(f"Portfolio Return Standard Deviation: {std:.7f}")
# Out:
# Sharpe Ratio: 2.1954000 (50% 1.0977000)
# Portfolio Return Mean: 0.0161995
# Portfolio Return Standard Deviation: 0.0076047

# %% [markdown]
# # Interest Rate Sensitive

# %% [markdown]
# ## Load Pricing Time Series

# %%
# ticker symbols
ticker_lst = list(folio_int_df['Ticker'])
print('ticker #:', len(ticker_lst))


# portfolio weights
weight_lst = (folio_int_df['port_percent'].values)
print('price #:', len(weight_lst))


#Download closing prices
#price_df = pdr.get_data_yahoo(ticker_lst, start=start_date, end=end_date)['Close']
price_int_df = pdr.get_data_yahoo(ticker_lst, period=period)['Close']

#price_df['C_A_S_H'] = 1
#print('price_df #:', len(price_df.columns))

#From the closing prices, calculate periodic returns
return_int_df = price_int_df.pct_change()
print('return_df #:', len(return_int_df.columns))
# Out:
# ticker #: 14
# price #: 14
# [*********************100%%**********************]  14 of 14 completed
# return_df #: 14

# %%
plt.figure(figsize=(20,10))
mask = np.zeros_like(price_int_df.corr())
mask[np.triu_indices_from(mask)] = True
sns.set_style("white")
_p = sns.heatmap(price_int_df.corr().round(2), 
                 annot=True, mask=mask, 
                 cmap="plasma", annot_kws={"size": 10})

# %% [markdown]
# ## Portfolio Returns

# %%
port_ret_weighted= return_int_df.mul(weight_lst, axis=1)
print('port_ret_weighted #:', len(port_ret_weighted))

return_int_df['Portfolio']= port_ret_weighted.sum(axis=1).dropna()
print('return_int_df #:', return_int_df.columns.shape)
# Out:
# port_ret_weighted #: 1259
# return_int_df #: (15,)

# %%
#tickers='^SP500BDT'
tickers = 'FHNFX'
BOND = pdr.get_data_yahoo(tickers=tickers, period=period)
return_int_df['Benchmark']= BOND['Close']
return_int_df['Benchmark']= return_int_df['Benchmark'].pct_change(1)

print('return_int_df #:', return_int_df.shape)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# return_int_df #: (1259, 16)

# %%
cum_ret_port = ((1 + return_int_df[['Portfolio','Benchmark']]).cumprod()-1)
cum_ret_port.plot(label='Cumulative Returns of the Portfolio' ,figsize=(19,8),title='Cumulative Returns - Interest Sensitive (vs ^FHNFX) ')
_=plt.xlabel('Date' )
_=plt.ylabel('Portfolio Cumulative Return' )

# %%
port_bench = pd.concat([return_int_df['Portfolio' ],return_int_df['Benchmark' ]],axis=1 ).dropna()
port_bench.columns=['Portfolio',' Benchmark' ]
correlation=port_bench.corr()
correlation
# Out:
#             Portfolio   Benchmark
# Portfolio    1.000000    0.848353
#  Benchmark   0.848353    1.000000

# %% [markdown]
# ## Sharpe Ratio

# %%
return_int_df['RF Rate']= rf_rate

sharpe_ratio=((return_int_df['Portfolio'].mean() - return_int_df['RF Rate'].mean()))/return_int_df['Portfolio' ].std()
sh = round(sharpe_ratio,4)
print(f"Sharpe Ratio: {sh:.7f} (50% {sh*0.5:.7f})")

avg = return_int_df['Portfolio'].mean() * 100
print(f"Portfolio Return Mean: {avg:.7f}")

std = return_int_df['Portfolio' ].std()
print(f"Portfolio Return Standard Deviation: {std:.7f}")
# Out:
# Sharpe Ratio: 18.1259000 (50% 9.0629500)
# Portfolio Return Mean: -0.0017504
# Portfolio Return Standard Deviation: 0.0009112
