# %%
# %matplotlib inline
import quantstats as qs

# %%
# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# fetch the daily returns for a stock
stock = qs.utils.download_returns('C')

# show sharpe ratio
qs.stats.sharpe(stock)

# or using extend_pandas() :)
stock.sharpe()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 0.24753088137042578

# %%
qs.plots.snapshot(stock, title='Facebook Performance')

# %%
stock.plot_snapshot(title='Facebook Performance')

# %%
qs.reports.full(stock, "SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               1993-02-01   1993-02-01
# End Period                 2023-10-20   2023-10-20
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       99.0%
#
# Cumulative Return          858.61%      -10.01%
# CAGR﹪                     5.21%        -0.24%
#
# Sharpe                     0.49         0.22
# Prob. Sharpe Ratio         99.63%       88.64%
# Smart Sharpe               0.47         0.21
# Sortino                    0.69         0.32
# Smart Sortino              0.67         0.31
# Sortino/√2                 0.48         0.23
# Smart Sortino/√2           0.47         0.22
# Omega                      1.05         1.05
#
# Max Drawdown               -56.47%      -98.27%
# Longest DD Days            2622         8453
# Volatility (ann.)          18.84%       45.12%
# R^2                        0.43         0.43
# Information Ratio          0.0          0.0
# Calmar                     0.09         -0.0
# Skew                       -0.05        1.27
# Kurtosis                   11.22        45.46
#
# Expected Daily %           0.03%        -0.0%
# Expected Monthly %         0.61%        -0.03%
# Expected Yearly %          7.56%        -0.34%
# Kelly Criterion            5.15%        -1.3%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -1.92%       -4.64%
# Expected Shortfall (cVaR)  -1.92%       -4.64%
#
# Max Consecutive Wins       14           12
# Max Consecutive Losses     8            14
# Gain/Pain Ratio            0.1          0.05
# Gain/Pain (1M)             0.58         0.23
#
# Payoff Ratio               0.95         0.98
# Profit Factor              1.1          1.05
# Common Sense Ratio         1.02         1.06
# CPC Index                  0.56         0.51
# Tail Ratio                 0.93         1.01
# Outlier Win Ratio          7.17         3.23
# Outlier Loss Ratio         6.19         3.02
#
# MTD                        -1.47%       -3.53%
# 3M                         -7.47%       -16.5%
# 6M                         1.7%         -21.27%
# YTD                        10.14%       -12.27%
# 1Y                         14.3%        -8.44%
# 3Y (ann.)                  3.94%        -6.26%
# 5Y (ann.)                  6.49%        -6.62%
# 10Y (ann.)                 6.28%        -1.74%
# All-time (ann.)            5.21%        -0.24%
#
# Best Day                   14.52%       57.82%
# Worst Day                  -10.94%      -39.02%
# Best Month                 12.7%        68.67%
# Worst Month                -16.52%      -57.75%
# Best Year                  34.95%       94.21%
# Worst Year                 -38.28%      -77.21%
#
# Avg. Drawdown              -2.16%       -7.72%
# Avg. Drawdown Days         34           139
# Recovery Factor            4.97         3.05
# Ulcer Index                0.17         0.66
# Serenity Index             0.62         0.11
#
# Avg. Up Month              3.66%        8.26%
# Avg. Down Month            -4.06%       -10.19%
# Win Days %                 53.72%       49.98%
# Win Month %                62.33%       55.28%
# Win Quarter %              69.35%       58.06%
# Win Year %                 70.97%       51.61%
#
# Beta                       -            1.57
# Alpha                      -            -0.05
# Correlation                -            65.58%
# Treynor Ratio              -            -6.37%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2000-08-29  2009-03-05  2023-10-20  8453    -98.267516        -95.565180
# 2  1998-04-07  1998-10-07  1999-04-07   366    -56.506849        -52.268836
# 3  1993-09-29  1994-07-12  1995-09-07   709    -37.373737        -36.616160
# 4  1997-02-19  1997-04-11  1997-06-06   108    -20.386271        -18.884122
# 5  2000-01-20  2000-02-25  2000-03-22    63    -19.665272        -17.991632
# <h4>Strategy Visualization</h4>

# %%
#

# %%
from py_vollib.black_scholes import black_scholes as bs
from py_vollib.black_scholes.greeks.analytical import delta, gamma, vega, theta, rho
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from py_vollib.black_scholes import black_scholes as bs
#       2 from py_vollib.black_scholes.greeks.analytical import delta, gamma, vega, theta, rho
#
# ModuleNotFoundError: No module named 'py_vollib'
