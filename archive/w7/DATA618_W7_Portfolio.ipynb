# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from pandas_datareader import data as pdr
from datetime import datetime, date, timedelta

# statistical analysis
import statsmodels.api as sm
from statsmodels import regression

import yfinance as yfin
yfin.pdr_override()

import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

#from var import VaR

pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
sns.set_theme(rc={'axes.formatter.limits': (-8, 9)})
#style.use('seaborn-whitegrid')
style.use("seaborn-white")
plt.rcParams["figure.figsize"] = (10,6)

# %% [markdown]
# # Weekly Tasks
# Prepare a presentation using Panopto (PowerPoint slides with Video Narration is an acceptable alternative) addressing the following points:
# What scenario were you assigned as the result of the random number exercise?
#
# - What were your considerations in determining an appropriate investment strategy for that scenario?
#
# - What asset allocation did you implement that you felt best supported that investment strategy?
#
# - What assets did you invest in consistent with that asset allocation and strategy? (Assets, Price at time of investment, % of total investment)
#
# - Present Value, Profit/Loss to date, VaR, SHARPE, VWAP, Alpha (Other metrics that you feel important in support of your strategy) for your portfolio
#
# What reallocation of assets would you recommend at this time (if any) and why?
# Post your presentation accessible to your colleagues for comment and comment on the presentations by your colleagues.

# %% [markdown]
# # Variables

# %%
start_date = datetime(2022, 1, 1)
purchase_date = datetime(2023, 9, 11)
purchase_date_str = '2023-9-11'
end_date = datetime.now()
end_date_str = end_date.strftime("%Y-%m-%d")

alpha = 0.05
period = '5y'

# %% [markdown]
# # Functions

# %%
def alpha(portfolio_returns, benchmark_returns):
    # mean of the return
    portfolio_avg_return = np.mean(portfolio_returns)
    benchmark_avg_return = np.mean(benchmark_returns)
    
    # volatility
    portfolio_volatility = np.std(portfolio_returns)
    benchmark_volatility = np.std(benchmark_returns)
    
    # our alpha
    alpha = (portfolio_avg_return - benchmark_avg_return) / (portfolio_volatility / benchmark_volatility)
    
    return alpha


def linreg(x,y):
    x = sm.add_constant(x) # add a column of 1s to our data (for intercept)
    model = regression.linear_model.OLS(y,x).fit()
    x = x[:, 1] # remove the constant
    return model.params[0], model.params[1]

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Load Variables

# %%
var_lst = ['GSPCX']
bench_df = pdr.get_data_yahoo(var_lst, start=purchase_date, end=end_date)['Close']
#bench_df = round((bench_df.mean() / 100),4)
bench_df = pd.DataFrame(bench_df)
bench_df.columns = ['GSPCX']

benchPercent_df = bench_df.pct_change()[1:]
benchPercent_df.reset_index(inplace=True)
benchPercent_df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date   GSPCX
# 0 2023-09-12 -0.0066
# 1 2023-09-13  0.0000
# 2 2023-09-14  0.0067
# 3 2023-09-15 -0.0110
# 4 2023-09-18  0.0000

# %%
var_lst = ['GSPCX']
bench_econ_df = pdr.get_data_yahoo(var_lst, start=purchase_date, end=end_date)['Close']
#bench_econ_df = round((bench_econ_df.mean() / 100),4)
bench_econ_df = pd.DataFrame(bench_econ_df)
bench_econ_df.columns = ['GSPCX']

benchPercent_econ_df = bench_econ_df.pct_change()[1:]
benchPercent_econ_df.reset_index(inplace=True)
benchPercent_econ_df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date   GSPCX
# 0 2023-09-12 -0.0066
# 1 2023-09-13  0.0000
# 2 2023-09-14  0.0067
# 3 2023-09-15 -0.0110
# 4 2023-09-18  0.0000

# %%
var_lst = ['AGG']
bench_int_df = pdr.get_data_yahoo(var_lst, start=purchase_date, end=end_date)['Close']
#bench_int_df = round((bench_int_df.mean() / 100),4)
bench_int_df = pd.DataFrame(bench_int_df)
bench_int_df.columns = ['AGG']

benchPercent_int_df = bench_int_df.pct_change()[1:]
benchPercent_int_df.reset_index(inplace=True)
benchPercent_int_df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date     AGG
# 0 2023-09-12  0.0003
# 1 2023-09-13  0.0015
# 2 2023-09-14 -0.0014
# 3 2023-09-15 -0.0023
# 4 2023-09-18  0.0015

# %%
folio_df = pd.read_csv('https://raw.githubusercontent.com/dsimband/DATA618/main/w7/data/DATA618_Portfolio.csv', 
                 dtype={
                    'ID': 'int',
                    'Price': 'float',
                    'Shares': 'float',
                    'Value': 'float', 
                 })

folio_df = folio_df[folio_df['Shares'] > 0]
folio_df = folio_df.groupby(['Ticker','BondName','Class','Sub_Class'])[['Shares','Value']].sum()
folio_df.reset_index(inplace=True)

# calculate portfilio percentage
portfolio_total = folio_df['Value'].sum()
folio_df['port_percent'] = folio_df['Value'] / portfolio_total

# Class Portfolios
folio_econ_df = folio_df[folio_df['Class'] == 'Economically Sensitive']
folio_int_df = folio_df[folio_df['Class'] == 'Interest Rate Sensitive']

folio_df
# Out:
#      Ticker                                  BondName  \
# 0     ALTVX      AB Municipal Income National Advisor
# 1     BLUEX          AMG Veritas Global Real Return I
# 2     BPLSX   Boston Partners Long/Short Equity Instl
# 3   C_A_S_H                                      Cash
# 4      DFAR            Dimensional US Real Estate ETF
# 5      FREL             Fidelity MSCI Real Estate ETF
# 6      FSMD        Fidelity Small-Mid Multifactor ETF
# 7     GARIX      Gotham Absolute Return Institutional
# 8     GCHDX          Gotham Hedged Core Institutional
# 9     ICBFX                 Invesco Corporate Bond R6
# 10    IGMWX                        Voya GNMA Income W
# 11     IGRO     iShares International Dividend Gr ETF
# 12     IMCB           iShares Morningstar Mid-Cap ETF
# 13     ISCF    iShares MSCI Intl Small-Cap Mltfct ETF
# 14      IVV                  iShares Core S&P 500 ETF
# 15     JPEM  JPMorgan Diversified Return EMkts Eq ETF
# 16     JPRE                JPMorgan Realty Income ETF
# 17     MEAR   iShares Short Maturity Municipal Bd ETF
# 18     MMIN           IQ MacKay Municipal Insured ETF
# 19     MMIT      IQ MacKay Municipal Intermediate ETF
# 20      PEX    ProShares Global Listed Private Equity
# 21    PFRAX    PIMCO International Bond (USD-Hdg) Adm
# 22    PSAIX  PIMCO Global Advantage Strategy Bd Instl
# 23     SCHD            Schwab US Dividend Equity ETF™
# 24    SNDPX                  AB Diversified Municipal
# 25    SWRSX   Schwab Treasury Infl Protected Secs Idx
# 26      VBR              Vanguard Small-Cap Value ETF
# 27    VFIUX         Vanguard Interm-Term Treasury Adm
# 28    VGCAX       Vanguard Global Credit Bond Admiral
# 29    VICSX  Vanguard Interm-Term Corp Bd Idx Admiral
# 30     VIGI              Vanguard Intl Div Apprec ETF
# 31      VNQ                  Vanguard Real Estate ETF
# 32       VO                      Vanguard Mid-Cap ETF
# 33     VONG          Vanguard Russell 1000 Growth ETF
# 34     VTEB              Vanguard Tax-Exempt Bond ETF
#
#                       Class                          Sub_Class         Shares  \
# 0   Interest Rate Sensitive  Very-High-Quality Municipal Bonds   106,383.0000
# 1    Economically Sensitive                Long/Short Equities    14,201.0000
# 2    Economically Sensitive                Long/Short Equities    49,967.0000
# 3                      Cash                               Cash 4,182,856.0000
# 4    Economically Sensitive              Publicly Traded REITs   108,467.0000
# 5    Economically Sensitive              Publicly Traded REITs   115,479.0000
# 6    Economically Sensitive                      U.S. Equities   120,705.0000
# 7    Economically Sensitive                Long/Short Equities    25,278.0000
# 8    Economically Sensitive                Long/Short Equities    46,211.0000
# 9   Interest Rate Sensitive  Very-High-Quality Corporate Bonds   166,389.0000
# 10  Interest Rate Sensitive              U.S. Government Bonds   763,889.0000
# 11   Economically Sensitive             International Equities    32,610.0000
# 12   Economically Sensitive                      U.S. Equities    64,494.0000
# 13   Economically Sensitive             International Equities    98,007.0000
# 14   Economically Sensitive                      U.S. Equities     8,912.0000
# 15   Economically Sensitive           Emerging Market Equities    78,561.0000
# 16   Economically Sensitive              Publicly Traded REITs    60,695.0000
# 17  Interest Rate Sensitive  Very-High-Quality Municipal Bonds    20,060.0000
# 18  Interest Rate Sensitive  Very-High-Quality Municipal Bonds    42,553.0000
# 19  Interest Rate Sensitive  Very-High-Quality Municipal Bonds    41,771.0000
# 20   Economically Sensitive                     Private Equity   150,754.0000
# 21  Interest Rate Sensitive  Very-High-Quality Corporate Bonds   105,820.0000
# 22  Interest Rate Sensitive  Very-High-Quality Corporate Bonds   103,413.0000
# 23   Economically Sensitive                      U.S. Equities    41,027.0000
# 24  Interest Rate Sensitive  Very-High-Quality Municipal Bonds    73,529.0000
# 25  Interest Rate Sensitive              U.S. Government Bonds   592,300.0000
# 26   Economically Sensitive                      U.S. Equities     6,120.0000
# 27  Interest Rate Sensitive              U.S. Government Bonds   566,426.0000
# 28  Interest Rate Sensitive  Very-High-Quality Corporate Bonds    54,437.0000
# 29  Interest Rate Sensitive  Very-High-Quality Corporate Bonds    95,923.0000
# 30   Economically Sensitive             International Equities    40,481.0000
# 31   Economically Sensitive              Publicly Traded REITs    40,221.0000
# 32   Economically Sensitive                      U.S. Equities     9,234.0000
# 33   Economically Sensitive                      U.S. Equities    41,501.0000
# 34  Interest Rate Sensitive  Very-High-Quality Municipal Bonds    20,333.0000
#
#         Value  port_percent
# 0  1,000.0000        0.0120
# 1    500.0000        0.0060
# 2    750.0000        0.0090
# 3  4,183.0000        0.0501
# 4  2,250.0000        0.0270
# 5  2,800.0000        0.0336
# 6  4,000.0000        0.0479
# 7    500.0000        0.0060
# 8    500.0000        0.0060
# 9  1,000.0000        0.0120
# 10 5,500.0000        0.0659
# 11 2,000.0000        0.0240
# 12 4,000.0000        0.0479
# 13 3,000.0000        0.0360
# 14 4,000.0000        0.0479
# 15 4,000.0000        0.0479
# 16 2,500.0000        0.0300
# 17 1,000.0000        0.0120
# 18 1,000.0000        0.0120
# 19 1,000.0000        0.0120
# 20 4,200.0000        0.0503
# 21 1,000.0000        0.0120
# 22 1,000.0000        0.0120
# 23 3,000.0000        0.0360
# 24 1,000.0000        0.0120
# 25 6,000.0000        0.0719
# 26 1,000.0000        0.0120
# 27 5,500.0000        0.0659
# 28 1,000.0000        0.0120
# 29 2,000.0000        0.0240
# 30 3,000.0000        0.0360
# 31 3,250.0000        0.0390
# 32 2,000.0000        0.0240
# 33 3,000.0000        0.0360
# 34 1,000.0000        0.0120

# %%
folio_df.groupby(['Class'])[['Value']].sum()
# Out:
#                               Value
# Class
# Cash                     4,183.0000
# Economically Sensitive  50,250.0000
# Interest Rate Sensitive 29,000.0000

# %%
initial_investment = folio_df['Value'].sum() * 1000
initial_investment
# Out:
# 83433000.0

# %% [markdown]
# # 4. Portfolio

# %% [markdown]
# ## 4.1 Load Pricing Time Series

# %%
# ticker symbols
ticker_lst = list(folio_df['Ticker'])
print('ticker #:', len(ticker_lst))

# portfolio weights
weight_lst = (folio_df['port_percent'].values)
print('price #:', len(weight_lst))

#Download closing prices
price_df = pdr.get_data_yahoo(ticker_lst, start=purchase_date, end=end_date)['Close']
price_df['C_A_S_H'] = 1
print('price_df #:', price_df.shape)

#From the closing prices, calculate periodic returns
return_df = price_df.pct_change()
return_df.fillna(0, inplace=True)
return_df.index = pd.to_datetime(return_df.index)
print('return_df #:', len(return_df.columns))
# Out:
# ticker #: 35
# price #: 35
# [*********************100%%**********************]  35 of 35 completed
# 1 Failed download:
# ['C_A_S_H']: Exception('%ticker%: No timezone found, symbol may be delisted')
# price_df #: (25, 35)
# return_df #: 35

# %% [markdown]
# ## 4.2 Portfolio Returns

# %%
port_ret_weighted= return_df.mul(weight_lst, axis=1)
print('port_ret_weighted #:', port_ret_weighted.shape)

return_df['Portfolio'] = port_ret_weighted.sum(axis=1)
print('return_df #:', return_df.shape)
# Out:
# port_ret_weighted #: (25, 35)
# return_df #: (25, 36)

# %%
weight_lst
# Out:
# array([0.01198567, 0.00599283, 0.00898925, 0.05013604, 0.02696775,
#        0.03355986, 0.04794266, 0.00599283, 0.00599283, 0.01198567,
#        0.06592116, 0.02397133, 0.04794266, 0.035957  , 0.04794266,
#        0.04794266, 0.02996416, 0.01198567, 0.01198567, 0.01198567,
#        0.05033979, 0.01198567, 0.01198567, 0.035957  , 0.01198567,
#        0.07191399, 0.01198567, 0.06592116, 0.01198567, 0.02397133,
#        0.035957  , 0.03895341, 0.02397133, 0.035957  , 0.01198567])

# %% [markdown]
# # 5. Calculate Portfolio Value

# %%
shares_df = folio_df[['Ticker','Shares']]
shares_df.set_index('Ticker', drop=True, inplace=True)
shares_df.head()
# Out:
#                 Shares
# Ticker
# ALTVX     106,383.0000
# BLUEX      14,201.0000
# BPLSX      49,967.0000
# C_A_S_H 4,182,856.0000
# DFAR      108,467.0000

# %%
m_df = price_df.copy()
m_df.reset_index(inplace=True)
m_df = m_df.melt(id_vars=['Date'])
m_df.columns = ['Date','Ticker','Price']
m_df.head()
# Out:
#         Date Ticker  Price
# 0 2023-09-11  ALTVX 9.4000
# 1 2023-09-12  ALTVX 9.3900
# 2 2023-09-13  ALTVX 9.3900
# 3 2023-09-14  ALTVX 9.3800
# 4 2023-09-15  ALTVX 9.3800

# %%
l_df = folio_df[['Ticker','Class','Sub_Class']] #.drop_duplicates() 
print('l_df: ',l_df.shape)
# Out:
# l_df:  (35, 3)

# %%
merge_df = m_df.merge(l_df, how='outer', left_on='Ticker', right_on='Ticker').merge(shares_df,how='outer' ,left_on='Ticker', right_on='Ticker')
merge_df['share_value'] = merge_df['Price'] * merge_df['Shares']
merge_df['pct_share_value'] = merge_df.groupby(['Ticker'])[['share_value']].pct_change()

print('merge_df: ',merge_df.shape)
# Out:
# merge_df:  (875, 8)

# %%
merge_df
# Out:
#           Date Ticker   Price                    Class  \
# 0   2023-09-11  ALTVX  9.4000  Interest Rate Sensitive
# 1   2023-09-12  ALTVX  9.3900  Interest Rate Sensitive
# 2   2023-09-13  ALTVX  9.3900  Interest Rate Sensitive
# 3   2023-09-14  ALTVX  9.3800  Interest Rate Sensitive
# 4   2023-09-15  ALTVX  9.3800  Interest Rate Sensitive
# ..         ...    ...     ...                      ...
# 870 2023-10-09   VTEB 47.8100  Interest Rate Sensitive
# 871 2023-10-10   VTEB 47.8600  Interest Rate Sensitive
# 872 2023-10-11   VTEB 48.2100  Interest Rate Sensitive
# 873 2023-10-12   VTEB 48.1000  Interest Rate Sensitive
# 874 2023-10-13   VTEB 48.1600  Interest Rate Sensitive
#
#                              Sub_Class       Shares    share_value  \
# 0    Very-High-Quality Municipal Bonds 106,383.0000 1,000,000.1594
# 1    Very-High-Quality Municipal Bonds 106,383.0000   998,936.4065
# 2    Very-High-Quality Municipal Bonds 106,383.0000   998,936.4065
# 3    Very-High-Quality Municipal Bonds 106,383.0000   997,872.5522
# 4    Very-High-Quality Municipal Bonds 106,383.0000   997,872.5522
# ..                                 ...          ...            ...
# 870  Very-High-Quality Municipal Bonds  20,333.0000   972,120.7579
# 871  Very-High-Quality Municipal Bonds  20,333.0000   973,137.3924
# 872  Very-High-Quality Municipal Bonds  20,333.0000   980,253.9114
# 873  Very-High-Quality Municipal Bonds  20,333.0000   978,017.2690
# 874  Very-High-Quality Municipal Bonds  20,333.0000   979,237.2769
#
#      pct_share_value
# 0                NaN
# 1            -0.0011
# 2             0.0000
# 3            -0.0011
# 4             0.0000
# ..               ...
# 870           0.0061
# 871           0.0010
# 872           0.0073
# 873          -0.0023
# 874           0.0012
#
# [875 rows x 8 columns]

# %%
folioValue_df = merge_df.groupby(['Date'])[['share_value']].sum().reset_index()
folioValue_df['pct_change'] = folioValue_df['share_value'].pct_change()

print('folioValue_df: ',folioValue_df.shape)
# Out:
# folioValue_df:  (25, 3)

# %%
fv_df = merge_df.groupby(['Date','Class'])[['share_value']].sum().reset_index()
fv_df['pct_change'] = fv_df.groupby(['Class'])[['share_value']].pct_change()

print('folioValue_df: ',fv_df.shape)
# Out:
# folioValue_df:  (75, 4)

# %% [markdown]
# ## 5.1 Portfolio Value

# %%
folio_df
# Out:
#      Ticker                                  BondName  \
# 0     ALTVX      AB Municipal Income National Advisor
# 1     BLUEX          AMG Veritas Global Real Return I
# 2     BPLSX   Boston Partners Long/Short Equity Instl
# 3   C_A_S_H                                      Cash
# 4      DFAR            Dimensional US Real Estate ETF
# 5      FREL             Fidelity MSCI Real Estate ETF
# 6      FSMD        Fidelity Small-Mid Multifactor ETF
# 7     GARIX      Gotham Absolute Return Institutional
# 8     GCHDX          Gotham Hedged Core Institutional
# 9     ICBFX                 Invesco Corporate Bond R6
# 10    IGMWX                        Voya GNMA Income W
# 11     IGRO     iShares International Dividend Gr ETF
# 12     IMCB           iShares Morningstar Mid-Cap ETF
# 13     ISCF    iShares MSCI Intl Small-Cap Mltfct ETF
# 14      IVV                  iShares Core S&P 500 ETF
# 15     JPEM  JPMorgan Diversified Return EMkts Eq ETF
# 16     JPRE                JPMorgan Realty Income ETF
# 17     MEAR   iShares Short Maturity Municipal Bd ETF
# 18     MMIN           IQ MacKay Municipal Insured ETF
# 19     MMIT      IQ MacKay Municipal Intermediate ETF
# 20      PEX    ProShares Global Listed Private Equity
# 21    PFRAX    PIMCO International Bond (USD-Hdg) Adm
# 22    PSAIX  PIMCO Global Advantage Strategy Bd Instl
# 23     SCHD            Schwab US Dividend Equity ETF™
# 24    SNDPX                  AB Diversified Municipal
# 25    SWRSX   Schwab Treasury Infl Protected Secs Idx
# 26      VBR              Vanguard Small-Cap Value ETF
# 27    VFIUX         Vanguard Interm-Term Treasury Adm
# 28    VGCAX       Vanguard Global Credit Bond Admiral
# 29    VICSX  Vanguard Interm-Term Corp Bd Idx Admiral
# 30     VIGI              Vanguard Intl Div Apprec ETF
# 31      VNQ                  Vanguard Real Estate ETF
# 32       VO                      Vanguard Mid-Cap ETF
# 33     VONG          Vanguard Russell 1000 Growth ETF
# 34     VTEB              Vanguard Tax-Exempt Bond ETF
#
#                       Class                          Sub_Class         Shares  \
# 0   Interest Rate Sensitive  Very-High-Quality Municipal Bonds   106,383.0000
# 1    Economically Sensitive                Long/Short Equities    14,201.0000
# 2    Economically Sensitive                Long/Short Equities    49,967.0000
# 3                      Cash                               Cash 4,182,856.0000
# 4    Economically Sensitive              Publicly Traded REITs   108,467.0000
# 5    Economically Sensitive              Publicly Traded REITs   115,479.0000
# 6    Economically Sensitive                      U.S. Equities   120,705.0000
# 7    Economically Sensitive                Long/Short Equities    25,278.0000
# 8    Economically Sensitive                Long/Short Equities    46,211.0000
# 9   Interest Rate Sensitive  Very-High-Quality Corporate Bonds   166,389.0000
# 10  Interest Rate Sensitive              U.S. Government Bonds   763,889.0000
# 11   Economically Sensitive             International Equities    32,610.0000
# 12   Economically Sensitive                      U.S. Equities    64,494.0000
# 13   Economically Sensitive             International Equities    98,007.0000
# 14   Economically Sensitive                      U.S. Equities     8,912.0000
# 15   Economically Sensitive           Emerging Market Equities    78,561.0000
# 16   Economically Sensitive              Publicly Traded REITs    60,695.0000
# 17  Interest Rate Sensitive  Very-High-Quality Municipal Bonds    20,060.0000
# 18  Interest Rate Sensitive  Very-High-Quality Municipal Bonds    42,553.0000
# 19  Interest Rate Sensitive  Very-High-Quality Municipal Bonds    41,771.0000
# 20   Economically Sensitive                     Private Equity   150,754.0000
# 21  Interest Rate Sensitive  Very-High-Quality Corporate Bonds   105,820.0000
# 22  Interest Rate Sensitive  Very-High-Quality Corporate Bonds   103,413.0000
# 23   Economically Sensitive                      U.S. Equities    41,027.0000
# 24  Interest Rate Sensitive  Very-High-Quality Municipal Bonds    73,529.0000
# 25  Interest Rate Sensitive              U.S. Government Bonds   592,300.0000
# 26   Economically Sensitive                      U.S. Equities     6,120.0000
# 27  Interest Rate Sensitive              U.S. Government Bonds   566,426.0000
# 28  Interest Rate Sensitive  Very-High-Quality Corporate Bonds    54,437.0000
# 29  Interest Rate Sensitive  Very-High-Quality Corporate Bonds    95,923.0000
# 30   Economically Sensitive             International Equities    40,481.0000
# 31   Economically Sensitive              Publicly Traded REITs    40,221.0000
# 32   Economically Sensitive                      U.S. Equities     9,234.0000
# 33   Economically Sensitive                      U.S. Equities    41,501.0000
# 34  Interest Rate Sensitive  Very-High-Quality Municipal Bonds    20,333.0000
#
#         Value  port_percent
# 0  1,000.0000        0.0120
# 1    500.0000        0.0060
# 2    750.0000        0.0090
# 3  4,183.0000        0.0501
# 4  2,250.0000        0.0270
# 5  2,800.0000        0.0336
# 6  4,000.0000        0.0479
# 7    500.0000        0.0060
# 8    500.0000        0.0060
# 9  1,000.0000        0.0120
# 10 5,500.0000        0.0659
# 11 2,000.0000        0.0240
# 12 4,000.0000        0.0479
# 13 3,000.0000        0.0360
# 14 4,000.0000        0.0479
# 15 4,000.0000        0.0479
# 16 2,500.0000        0.0300
# 17 1,000.0000        0.0120
# 18 1,000.0000        0.0120
# 19 1,000.0000        0.0120
# 20 4,200.0000        0.0503
# 21 1,000.0000        0.0120
# 22 1,000.0000        0.0120
# 23 3,000.0000        0.0360
# 24 1,000.0000        0.0120
# 25 6,000.0000        0.0719
# 26 1,000.0000        0.0120
# 27 5,500.0000        0.0659
# 28 1,000.0000        0.0120
# 29 2,000.0000        0.0240
# 30 3,000.0000        0.0360
# 31 3,250.0000        0.0390
# 32 2,000.0000        0.0240
# 33 3,000.0000        0.0360
# 34 1,000.0000        0.0120

# %%
folio_df.groupby(['Class','Sub_Class'])[['Value']].sum()
# Out:
#                                                                 Value
# Class                   Sub_Class
# Cash                    Cash                               4,183.0000
# Economically Sensitive  Emerging Market Equities           4,000.0000
#                         International Equities             8,000.0000
#                         Long/Short Equities                2,250.0000
#                         Private Equity                     4,200.0000
#                         Publicly Traded REITs             10,800.0000
#                         U.S. Equities                     21,000.0000
# Interest Rate Sensitive U.S. Government Bonds             17,000.0000
#                         Very-High-Quality Corporate Bonds  6,000.0000
#                         Very-High-Quality Municipal Bonds  6,000.0000

# %%
folio_df[['Value']].sum()
# Out:
# Value   83,433.0000
# dtype: float64

# %% [markdown]
# ## Graph Porfolio Values

# %%
folioValue_df[folioValue_df['Date'] == purchase_date.strftime("%Y-%m-%d")]
# Out:
#         Date     share_value  pct_change
# 0 2023-09-11 83,718,683.5760         NaN

# %%
folioValue_df[folioValue_df['Date'] == max(folioValue_df['Date']).strftime("%Y-%m-%d")]
# Out:
#          Date     share_value  pct_change
# 24 2023-10-13 80,509,926.6287     -0.0018

# %%
r1_df = folioValue_df.loc[(folioValue_df['Date'] == min(folioValue_df['Date']))
                     | (folioValue_df['Date'] == max(folioValue_df['Date']))]
print('Portfolio Return: ',r1_df['share_value'].pct_change()[-1:].values)
# Out:
# Portfolio Return:  [-0.03832785]

# %%
r1_df = bench_df.loc[(bench_df.index == min(bench_df.index))
                     | (bench_df.index == max(bench_df.index))]
print('Benchmark Return: ',r1_df['GSPCX'].pct_change()[-1:].values)
# Out:
# Benchmark Return:  [-0.04485298]

# %%
m1_df = folioValue_df.merge(benchPercent_df, how='outer', left_on='Date', right_on='Date')
m1_df.head()
# Out:
#         Date     share_value  pct_change   GSPCX
# 0 2023-09-11 83,718,683.5760         NaN     NaN
# 1 2023-09-12 83,597,204.6712     -0.0015 -0.0066
# 2 2023-09-13 83,425,622.0770     -0.0021  0.0000
# 3 2023-09-14 83,951,847.4157      0.0063  0.0067
# 4 2023-09-15 83,535,984.2190     -0.0050 -0.0110

# %%
# Graph
fig, ax = plt.subplots(figsize=(16,8))
plt.ticklabel_format(style='plain', axis='y')

ax.set_ylim(-.05, 0.05)
ax.tick_params(axis='x', labelrotation=90) 
xticks = xticks = m1_df['Date'].tolist()
ax.set_xticklabels([pd.to_datetime(tm, unit='d').strftime('%b-%d') for tm in xticks])

# Plot
sns.set_style("white")
g = sns.lineplot(data=m1_df, x="Date", y="pct_change", color='darkblue')
g = sns.lineplot(data=m1_df, x="Date", y="GSPCX", color='red', linestyle="dashed")
#ax = sns.lineplot(x=x, y=y, linestyle="dashed")
g.set_yticklabels(['{:,.1f}'.format(x) + ' %' for x in g.get_yticks() * 100])

plt.axhline(y=0, linestyle="dashed", color='lightgray')

ax.set(title='Portfolio Performance (vs GSPCX)');

# %%
t1_df = m1_df.copy()
t1_df['Date'] = t1_df['Date'].dt.strftime("%Y-%m-%d")
t1_df.head()
# Out:
#          Date     share_value  pct_change   GSPCX
# 0  2023-09-11 83,718,683.5760         NaN     NaN
# 1  2023-09-12 83,597,204.6712     -0.0015 -0.0066
# 2  2023-09-13 83,425,622.0770     -0.0021  0.0000
# 3  2023-09-14 83,951,847.4157      0.0063  0.0067
# 4  2023-09-15 83,535,984.2190     -0.0050 -0.0110

# %%
fig, ax1 = plt.subplots(figsize=(16,8))

sns.barplot(data = t1_df, x='Date', y='share_value', alpha=0.60, color='darkblue',  ax=ax1)
ax2 = ax1.twinx()
sns.lineplot(color='red' , linestyle="dashed" ,sort=False, data = t1_df, x='Date',y ='GSPCX',dashes=True, ax=ax2)
sns.lineplot(color='darkblue' , marker='o' ,sort=False, data = t1_df, x='Date', y='pct_change',ax=ax2)


ax1.set_ylim(75000000, 90000000)
ax2.set_ylim(-.08, 0.02)

ax1.tick_params(axis='x', labelrotation=90) 
xticks = xticks = m1_df['Date'].tolist()
ax1.set_xticklabels([pd.to_datetime(tm, unit='d').strftime('%b-%d') for tm in xticks])
ax1.set_yticklabels(['{:,.1f}'.format(y) + ' M' for y in ax1.get_yticks()/1000000])
ax2.set_yticklabels(['{:,.2f}'.format(y) + ' %' for y in ax2.get_yticks()*100])

# annotations
ax2.set_title('Overall Portfolio Performance (vs GSPCX)')
ax2.set(xlabel='month', ylabel='return')
ax1.set(ylabel='market value')

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,8))
ax2 = ax1.twinx()

ax1.set_ylim(75000000, 90000000)
ax2.set_ylim(-.08, 0.02)


sns.barplot(data = m1_df, x='Date', y='share_value', alpha=0.5, color='darkblue', width=.5, ax=ax1)
#sns.lineplot(data = m1_df, x='Date', y = 'pct_change' , marker='o',color='darkblue',sort=False, ax=ax2)
#sns.lineplot(data = m1_df.set_index('Date')[['share_value']] , marker='o',color='darkblue',sort=False, ax=ax2)


fig.autofmt_xdate()
ax1.tick_params(axis='x', labelrotation=90) 
xticks = xticks = m1_df['Date'].tolist()
ax1.set_xticklabels([pd.to_datetime(tm, unit='d').strftime('%b-%d') for tm in xticks])
ax1.set_yticklabels(['{:,.1f}'.format(y) + ' M' for y in ax1.get_yticks()/1000000])


#sns.lineplot(data = m1_df['pct_change'], marker='o' ,color='darkblue',sort=False, ax=ax2)
#ax2 = sns.lineplot(data = m1_df, x='Date', y = 'pct_change' , marker='o' ,color='darkblue',sort=False)
#m1_df.plot(x="Date", y="pct_change", legend=False, ax=g.axes.twinx())
#sns.lineplot(data = m1_df['GSPCX'], color='red' , linestyle="dashed" ,sort=False, ax=ax2)
plt.axhline(y=0, linestyle="dashed", color='lightgray')


# annotations
ax2.set_title('Overall Portfolio Performance (vs GSPCX)')
ax2.set(xlabel='month', ylabel='return')
ax1.set(ylabel='market value')

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,8))
sns.lineplot(data = m1_df[['Date','pct_change']], x='Date', y='pct_change',marker='o' ,color='darkblue',sort=False, ax=ax1)
sns.lineplot(data = m1_df[['Date','GSPCX']], color='red' ,x='Date', y='GSPCX', linestyle="dashed" ,sort=False, ax=ax1)
plt.axhline(y=0, linestyle="dashed", color='lightgray')

ax2 = ax1.twinx()
sns.barplot(data = m1_df, x='Date', y='share_value', alpha=0.5, ax=ax2, color='darkblue', width=.5)

ax1.set_ylim(-.08, 0.02)
ax2.set_ylim(75000000, 90000000)
#ax2.set_ylim(0, 150000000)

#fig.autofmt_xdate()
ax1.tick_params(axis='x', labelrotation=90) 
#xticks = xticks = m1_df['Date'].tolist()
#xticks2 = xticks = t1_df['Date'].tolist()
#ax1.set_xticklabels([pd.to_datetime(tm, unit='d').strftime('%b-%d') for tm in xticks])
#ax2.set_xticklabels([pd.to_datetime(tm, unit='d').strftime('%b-%d') for tm in xticks2])

# annotations
ax1.set_title('Overall Portfolio Performance (vs GSPCX)')
ax1.set(xlabel='month', ylabel='enrollment %')
ax2.set(ylabel='enrollment #')

plt.show()

# %%
#
m2_df = folioValue_df.merge(benchPercent_econ_df, how='outer', left_on='Date', right_on='Date')
#m1_df = m1_df.melt(id_vars=['Date'])
m2_df.head()
# Out:
#         Date     share_value  pct_change   GSPCX
# 0 2023-09-11 83,718,683.5760         NaN     NaN
# 1 2023-09-12 83,597,204.6712     -0.0015 -0.0066
# 2 2023-09-13 83,425,622.0770     -0.0021  0.0000
# 3 2023-09-14 83,951,847.4157      0.0063  0.0067
# 4 2023-09-15 83,535,984.2190     -0.0050 -0.0110

# %%
t_df = fv_df[fv_df['Class'] == 'Economically Sensitive']
t_df.head()
# Out:
#          Date                   Class     share_value  pct_change
# 1  2023-09-11  Economically Sensitive 50,535,872.6588         NaN
# 4  2023-09-12  Economically Sensitive 50,401,357.6570     -0.0027
# 7  2023-09-13  Economically Sensitive 50,201,477.5737     -0.0040
# 10 2023-09-14  Economically Sensitive 50,758,492.1692      0.0111
# 13 2023-09-15  Economically Sensitive 50,399,819.5650     -0.0071

# %%
fig, ax = plt.subplots(figsize=(16,8))
sns.lineplot(data = m2_df,x='Date',y='pct_change', color='red' , linestyle="dashed" ,sort=False, ax=ax)
sns.lineplot(data = t_df,x='Date',y='pct_change', marker='o' ,color='darkblue',sort=True, ax=ax)
plt.show()

# %%
t_df[['Date','pct_change']]
# Out:
#          Date  pct_change
# 1  2023-09-11         NaN
# 4  2023-09-12     -0.0027
# 7  2023-09-13     -0.0040
# 10 2023-09-14      0.0111
# 13 2023-09-15     -0.0071
# 16 2023-09-18     -0.0033
# 19 2023-09-19     -0.0040
# 22 2023-09-20     -0.0074
# 25 2023-09-21     -0.0188
# 28 2023-09-22     -0.0019
# 31 2023-09-25      0.0010
# 34 2023-09-26     -0.0151
# 37 2023-09-27     -0.0010
# 40 2023-09-28      0.0070
# 43 2023-09-29     -0.0007
# 46 2023-10-02     -0.0111
# 49 2023-10-03     -0.0143
# 52 2023-10-04      0.0054
# 55 2023-10-05      0.0024
# 58 2023-10-06      0.0081
# 61 2023-10-09      0.0057
# 64 2023-10-10      0.0073
# 67 2023-10-11      0.0064
# 70 2023-10-12     -0.0107
# 73 2023-10-13     -0.0050

# %%
fig, ax1 = plt.subplots(figsize=(16,8))
ax2 = ax1.twinx()

#sns.lineplot(data = t_df[['Date','pct_change']], marker='o' ,color='darkblue',sort=False, ax=ax1)
sns.lineplot(data = t_df, x='Date', y='pct_change', marker='o' ,color='darkblue',sort=True, ax=ax1)
#sns.lineplot(data = m2_df['GSPCX'], color='red' , linestyle="dashed" ,sort=False, ax=ax1)
sns.lineplot(data = m2_df,x='Date',y='pct_change', color='red' , linestyle="dashed" ,sort=True, ax=ax1)
plt.axhline(y=0, linestyle="dashed", color='lightgray')


#sns.barplot(data = m1_df, x='Date', y='share_value', alpha=0.5, ax=ax2, color='darkblue', width=.5)
sns.barplot(data = t_df, x='Date', y='share_value',errorbar=None,alpha=0.5, ax=ax2, color='darkblue', width=.5)

ax1.set_ylim(-.15, 0.05)
ax2.set_ylim(40000000, 60000000)

fig.autofmt_xdate()
ax1.tick_params(axis='x', labelrotation=90) 
xticks = xticks = m1_df['Date'].tolist()
ax2.set_xticklabels([pd.to_datetime(tm, unit='d').strftime('%b-%d') for tm in xticks])

# annotations
ax1.set_title('Economically Sensitive Portfolio Performance (vs GSPCX)')
ax1.set(xlabel='month', ylabel='enrollment %')
ax2.set(ylabel='enrollment #')

plt.show()

# %%
t_df = fv_df[fv_df['Class'] == 'Interest Rate Sensitive']
t_df.head()
# Out:
#          Date                    Class     share_value  pct_change
# 2  2023-09-11  Interest Rate Sensitive 28,999,954.9171         NaN
# 5  2023-09-12  Interest Rate Sensitive 29,012,991.0141      0.0004
# 8  2023-09-13  Interest Rate Sensitive 29,041,288.5032      0.0010
# 11 2023-09-14  Interest Rate Sensitive 29,010,499.2465     -0.0011
# 14 2023-09-15  Interest Rate Sensitive 28,953,308.6540     -0.0020

# %%
fig, ax1 = plt.subplots(figsize=(16,8))
sns.lineplot(data = t_df['pct_change'], marker='o' ,color='darkblue',sort=False, ax=ax1)
sns.lineplot(data = benchPercent_int_df['AGG'], color='red' , linestyle="dashed" ,sort=False, ax=ax1)
plt.axhline(y=0, linestyle="dashed", color='lightgray')

ax2 = ax1.twinx()
#sns.barplot(data = m1_df, x='Date', y='share_value', alpha=0.5, ax=ax2, color='darkblue', width=.5)
sns.barplot(data = t_df, x='Date', y='share_value',errorbar=None,alpha=0.5, ax=ax2, color='darkblue', width=.5)

ax1.set_ylim(-.08, 0.02)
ax2.set_ylim(28000000, 30000000)

fig.autofmt_xdate()
ax1.tick_params(axis='x', labelrotation=90) 
xticks = xticks = m1_df['Date'].tolist()
ax2.set_xticklabels([pd.to_datetime(tm, unit='d').strftime('%b-%d') for tm in xticks])

# annotations
ax1.set_title('Interest Rate Sensitive Portfolio Performance (vs AGG)')
ax1.set(xlabel='month', ylabel='enrollment %')
ax2.set(ylabel='enrollment #')

plt.show()

# %% [markdown]
# # Alpha Calculations

# %% [markdown]
# # Economically Sensitive

# %%
#tickers='^DJA'
#tickers = 'FHNFX'
tickers='GSPCX'
bench_data = pdr.get_data_yahoo(tickers=tickers, start=purchase_date, end=end_date )
bench_econ_df= pd.DataFrame(bench_data['Close'])
bench_econ_df.columns = ['bench']
bench_econ_df['precent_bench']= bench_econ_df['bench'].pct_change(1)

print('bench_econ_df:', bench_econ_df.shape)
#bench_econ_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
# bench_econ_df: (25, 2)

# %%
ticker_lst = folio_econ_df['Ticker']
print('ticker_lst:', len(ticker_lst))

#value_econ_df = merge_df[merge_df['Ticker'].isin(ticker_lst)]
#print('value_econ_df:', value_econ_df.shape)
# Out:
# ticker_lst: 20

# %%
#merge_df[merge_df['Date'] == '2023-09-11'] | merge_df['Date'] == '2023-09-11']

# %%
alpha_econ_df = pd.DataFrame(columns=['Ticker','alpha','beta'])

for t in ticker_lst:
    X = bench_econ_df['precent_bench'].values
    y = merge_df[merge_df['Ticker'] == t]['pct_share_value'].values
    
    t_df = pd.DataFrame({'X':X,'y':y})
    t_df = t_df[np.isfinite(t_df).all(1)]
    
    alpha, beta = linreg(t_df.X.values,t_df.y.values)
    alpha_econ_df.loc[len(alpha_econ_df.index)] = [t, alpha, beta]
    
print('alpha_econ_df:', alpha_econ_df.shape)
# Out:
# alpha_econ_df: (20, 3)

# %% [markdown]
# ## Graph

# %%
set(merge_df['Class'])
# Out:
# {'Cash', 'Economically Sensitive', 'Interest Rate Sensitive'}

# %%
m_df = merge_df[merge_df['Class'] == 'Economically Sensitive']
#m_df = merge_df[(merge_df['Class'] == 'Economically Sensitive') & (merge_df['Ticker'] == 'BLUEX')]
m_df
# Out:
#           Date Ticker   Price                   Class            Sub_Class  \
# 25  2023-09-11  BLUEX 35.2100  Economically Sensitive  Long/Short Equities
# 26  2023-09-12  BLUEX 35.0800  Economically Sensitive  Long/Short Equities
# 27  2023-09-13  BLUEX 35.1400  Economically Sensitive  Long/Short Equities
# 28  2023-09-14  BLUEX 35.2400  Economically Sensitive  Long/Short Equities
# 29  2023-09-15  BLUEX 35.1600  Economically Sensitive  Long/Short Equities
# ..         ...    ...     ...                     ...                  ...
# 845 2023-10-09   VONG 70.2100  Economically Sensitive        U.S. Equities
# 846 2023-10-10   VONG 70.5100  Economically Sensitive        U.S. Equities
# 847 2023-10-11   VONG 71.0900  Economically Sensitive        U.S. Equities
# 848 2023-10-12   VONG 70.7600  Economically Sensitive        U.S. Equities
# 849 2023-10-13   VONG 70.0600  Economically Sensitive        U.S. Equities
#
#          Shares    share_value  pct_share_value
# 25  14,201.0000   500,017.1970              NaN
# 26  14,201.0000   498,171.1060          -0.0037
# 27  14,201.0000   499,023.1313           0.0017
# 28  14,201.0000   500,443.2638           0.0028
# 29  14,201.0000   499,307.1578          -0.0023
# ..          ...            ...              ...
# 845 41,501.0000 2,913,785.1720           0.0050
# 846 41,501.0000 2,926,235.5987           0.0043
# 847 41,501.0000 2,950,305.9380           0.0082
# 848 41,501.0000 2,936,610.8487          -0.0046
# 849 41,501.0000 2,907,559.9587          -0.0099
#
# [500 rows x 8 columns]

# %%
fig, ax = plt.subplots(figsize=(14,6))
t_df = alpha_econ_df.melt(id_vars='Ticker').rename(columns=str.title)
t_df = t_df[t_df['Variable'] == 'alpha']
g = sns.barplot(x='Value', y='Ticker', hue='Variable',data=t_df, ax=ax)
sns.despine(fig)
ax.set(title='Economically Sensitive Asset - Alpha Backtest (5 year)');

# %%
fig, ax = plt.subplots(figsize=(14,6))
t_df = alpha_econ_df.melt(id_vars='Ticker').rename(columns=str.title)
t_df = t_df[t_df['Variable'] == 'beta']
g = sns.barplot(x='Value', y='Ticker', color='red', data=t_df, ax=ax)
sns.despine(fig)
ax.set(title='Economically Sensitive Asset - Beta Backtest (5 year)');

# %% [markdown]
# # Interest Rate Sensitive

# %%
#tickers='^DJA'
#tickers = 'FHNFX'
tickers = 'AGG'
bench_data = pdr.get_data_yahoo(tickers=tickers, start=purchase_date, end=end_date )
bench_int_df= pd.DataFrame(bench_data['Close'])
bench_int_df.columns = ['bench']
bench_int_df['precent_bench']= bench_int_df['bench'].pct_change(1)

print('bench_int_df #:', bench_int_df.shape)
lb = len(bench_int_df)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# bench_int_df #: (25, 2)

# %%
ticker_lst = folio_int_df['Ticker']
print('ticker_lst:', len(ticker_lst))
# Out:
# ticker_lst: 14

# %%
alpha_int_df = pd.DataFrame(columns=['Ticker','alpha','beta'])

for t in ticker_lst:
    X = bench_int_df['precent_bench'].values
    y = merge_df[merge_df['Ticker'] == t][:lb]['pct_share_value'].values
    
    t_df = pd.DataFrame({'X':X,'y':y})
    t_df = t_df[np.isfinite(t_df).all(1)]
    
    alpha, beta = linreg(t_df.X.values,t_df.y.values)
    alpha_int_df.loc[len(alpha_int_df.index)] = [t, alpha, beta]
    
print('alpha_int_df:', alpha_int_df.shape)
# Out:
# alpha_int_df: (14, 3)

# %% [markdown]
# ## Graph

# %%
fig, ax = plt.subplots(figsize=(14,6))
t_df = alpha_int_df.melt(id_vars='Ticker').rename(columns=str.title)
t_df = t_df[t_df['Variable'] == 'alpha']
g = sns.barplot(x='Value', y='Ticker', hue='Variable',data=t_df, ax=ax)
sns.despine(fig)
ax.set(title='Interest Sensitive Asset - Alpha Backtest (5 year)');

# %%
fig, ax = plt.subplots(figsize=(14,6))
t_df = alpha_int_df.melt(id_vars='Ticker').rename(columns=str.title)
t_df = t_df[t_df['Variable'] == 'beta']
g = sns.barplot(x='Value', y='Ticker', color='red',data=t_df, ax=ax)
sns.despine(fig)
ax.set(title='Interest Sensitive Asset - Beta Backtest (5 year)');

# %% [markdown]
# # Performance

# %%
f_df = merge_df.loc[(merge_df['Date'] == min(merge_df['Date']))
                     | (merge_df['Date'] == max(merge_df['Date']))]
f_df['pct_share_value'] = merge_df.groupby(['Ticker'])[['share_value']].pct_change()
f_df = f_df.loc[(f_df['Date'] == max(f_df['Date']))]
print('f_df: ', f_df.shape)
# Out:
# f_df:  (35, 8)

# %%
alpha_int_df
# Out:
#    Ticker   alpha    beta
# 0   ALTVX -0.0006  0.3267
# 1   ICBFX -0.0003  0.8850
# 2   IGMWX -0.0001  1.1056
# 3    MEAR -0.0001 -0.0092
# 4    MMIN -0.0003  0.7829
# 5    MMIT -0.0004  0.4108
# 6   PFRAX -0.0002  0.1357
# 7   PSAIX -0.0003  0.3927
# 8   SNDPX -0.0005  0.1277
# 9   SWRSX -0.0003  0.8066
# 10  VFIUX  0.0000  0.6977
# 11  VGCAX -0.0003  0.6938
# 12  VICSX -0.0001  0.8863
# 13   VTEB -0.0003  0.6116

# %%
a_df = pd.concat([alpha_econ_df,alpha_int_df])
a_df
# Out:
#    Ticker   alpha    beta
# 0   BLUEX -0.0001  0.6271
# 1   BPLSX  0.0008  0.4683
# 2    DFAR -0.0006  1.1991
# 3    FREL -0.0006  1.2791
# 4    FSMD -0.0002  0.9686
# 5   GARIX  0.0007  0.6322
# 6   GCHDX -0.0001  0.5501
# 7    IGRO -0.0002  0.8168
# 8    IMCB -0.0000  1.0763
# 9    ISCF -0.0012  0.7709
# 10    IVV  0.0003  1.0268
# 11   JPEM -0.0010  0.5705
# 12   JPRE -0.0002  1.1489
# 13    PEX -0.0017  0.9211
# 14   SCHD -0.0005  0.7986
# 15    VBR -0.0002  1.0861
# 16   VIGI  0.0001  0.7730
# 17    VNQ -0.0010  1.1559
# 18     VO -0.0001  1.0488
# 19   VONG  0.0010  1.2306
# 0   ALTVX -0.0006  0.3267
# 1   ICBFX -0.0003  0.8850
# 2   IGMWX -0.0001  1.1056
# 3    MEAR -0.0001 -0.0092
# 4    MMIN -0.0003  0.7829
# 5    MMIT -0.0004  0.4108
# 6   PFRAX -0.0002  0.1357
# 7   PSAIX -0.0003  0.3927
# 8   SNDPX -0.0005  0.1277
# 9   SWRSX -0.0003  0.8066
# 10  VFIUX  0.0000  0.6977
# 11  VGCAX -0.0003  0.6938
# 12  VICSX -0.0001  0.8863
# 13   VTEB -0.0003  0.6116

# %%
f1_df = f_df.merge(a_df, how='outer', left_on='Ticker', right_on='Ticker') 
f1_df.fillna(0, inplace=True)
f1_df
# Out:
#          Date   Ticker    Price                    Class  \
# 0  2023-10-13    ALTVX   9.1900  Interest Rate Sensitive
# 1  2023-10-13    BLUEX  34.1300   Economically Sensitive
# 2  2023-10-13    BPLSX  14.9800   Economically Sensitive
# 3  2023-10-13  C_A_S_H   1.0000                     Cash
# 4  2023-10-13     DFAR  19.5500   Economically Sensitive
# 5  2023-10-13     FREL  22.7000   Economically Sensitive
# 6  2023-10-13     FSMD  31.6200   Economically Sensitive
# 7  2023-10-13    GARIX  19.5300   Economically Sensitive
# 8  2023-10-13    GCHDX  10.5300   Economically Sensitive
# 9  2023-10-13    ICBFX   5.8600  Interest Rate Sensitive
# 10 2023-10-13    IGMWX   7.0200  Interest Rate Sensitive
# 11 2023-10-13     IGRO  59.2000   Economically Sensitive
# 12 2023-10-13     IMCB  59.2600   Economically Sensitive
# 13 2023-10-13     ISCF  28.6800   Economically Sensitive
# 14 2023-10-13      IVV 433.4100   Economically Sensitive
# 15 2023-10-13     JPEM  49.2200   Economically Sensitive
# 16 2023-10-13     JPRE  39.1690   Economically Sensitive
# 17 2023-10-13     MEAR  49.7700  Interest Rate Sensitive
# 18 2023-10-13     MMIN  22.9200  Interest Rate Sensitive
# 19 2023-10-13     MMIT  23.5300  Interest Rate Sensitive
# 20 2023-10-13      PEX  25.5900   Economically Sensitive
# 21 2023-10-13    PFRAX   9.3800  Interest Rate Sensitive
# 22 2023-10-13    PSAIX   9.5300  Interest Rate Sensitive
# 23 2023-10-13     SCHD  70.3200   Economically Sensitive
# 24 2023-10-13    SNDPX  13.4100  Interest Rate Sensitive
# 25 2023-10-13    SWRSX   9.8900  Interest Rate Sensitive
# 26 2023-10-13      VBR 155.3700   Economically Sensitive
# 27 2023-10-13    VFIUX   9.5700  Interest Rate Sensitive
# 28 2023-10-13    VGCAX  17.9600  Interest Rate Sensitive
# 29 2023-10-13    VICSX  20.4000  Interest Rate Sensitive
# 30 2023-10-13     VIGI  71.9200   Economically Sensitive
# 31 2023-10-13      VNQ  75.4900   Economically Sensitive
# 32 2023-10-13       VO 206.6200   Economically Sensitive
# 33 2023-10-13     VONG  70.0600   Economically Sensitive
# 34 2023-10-13     VTEB  48.1600  Interest Rate Sensitive
#
#                             Sub_Class         Shares    share_value  \
# 0   Very-High-Quality Municipal Bonds   106,383.0000   977,659.7254
# 1                 Long/Short Equities    14,201.0000   484,680.1452
# 2                 Long/Short Equities    49,967.0000   748,505.6371
# 3                                Cash 4,182,856.0000 4,182,856.0000
# 4               Publicly Traded REITs   108,467.0000 2,120,529.7672
# 5               Publicly Traded REITs   115,479.0000 2,621,373.3881
# 6                       U.S. Equities   120,705.0000 3,816,692.2013
# 7                 Long/Short Equities    25,278.0000   493,679.3574
# 8                 Long/Short Equities    46,211.0000   486,601.8177
# 9   Very-High-Quality Corporate Bonds   166,389.0000   975,039.5622
# 10              U.S. Government Bonds   763,889.0000 5,362,500.7654
# 11             International Equities    32,610.0000 1,930,512.0249
# 12                      U.S. Equities    64,494.0000 3,821,914.3317
# 13             International Equities    98,007.0000 2,810,840.7899
# 14                      U.S. Equities     8,912.0000 3,862,549.9526
# 15           Emerging Market Equities    78,561.0000 3,866,772.5159
# 16              Publicly Traded REITs    60,695.0000 2,377,362.3772
# 17  Very-High-Quality Municipal Bonds    20,060.0000   998,386.2092
# 18  Very-High-Quality Municipal Bonds    42,553.0000   975,314.7632
# 19  Very-High-Quality Municipal Bonds    41,771.0000   982,871.6587
# 20                     Private Equity   150,754.0000 3,857,794.8830
# 21  Very-High-Quality Corporate Bonds   105,820.0000   992,591.6121
# 22  Very-High-Quality Corporate Bonds   103,413.0000   985,525.8624
# 23                      U.S. Equities    41,027.0000 2,885,018.6275
# 24  Very-High-Quality Municipal Bonds    73,529.0000   986,023.8788
# 25              U.S. Government Bonds   592,300.0000 5,857,847.2034
# 26                      U.S. Equities     6,120.0000   950,864.3701
# 27              U.S. Government Bonds   566,426.0000 5,420,696.6471
# 28  Very-High-Quality Corporate Bonds    54,437.0000   977,688.4702
# 29  Very-High-Quality Corporate Bonds    95,923.0000 1,956,829.1634
# 30             International Equities    40,481.0000 2,911,393.4459
# 31              Publicly Traded REITs    40,221.0000 3,036,283.2041
# 32                      U.S. Equities     9,234.0000 1,907,929.0349
# 33                      U.S. Equities    41,501.0000 2,907,559.9587
# 34  Very-High-Quality Municipal Bonds    20,333.0000   979,237.2769
#
#     pct_share_value   alpha    beta
# 0           -0.0011 -0.0006  0.3267
# 1           -0.0012 -0.0001  0.6271
# 2            0.0000  0.0008  0.4683
# 3            0.0000  0.0000  0.0000
# 4           -0.0010 -0.0006  1.1991
# 5           -0.0015 -0.0006  1.2791
# 6           -0.0072 -0.0002  0.9686
# 7           -0.0066  0.0007  0.6322
# 8            0.0000 -0.0001  0.5501
# 9            0.0051 -0.0003  0.8850
# 10           0.0043 -0.0001  1.1056
# 11          -0.0029 -0.0002  0.8168
# 12          -0.0057 -0.0000  1.0763
# 13          -0.0138 -0.0012  0.7709
# 14          -0.0053  0.0003  1.0268
# 15          -0.0016 -0.0010  0.5705
# 16          -0.0004 -0.0002  1.1489
# 17          -0.0002 -0.0001 -0.0092
# 18           0.0035 -0.0003  0.7829
# 19           0.0013 -0.0004  0.4108
# 20          -0.0093 -0.0017  0.9211
# 21           0.0000 -0.0002  0.1357
# 22           0.0000 -0.0003  0.3927
# 23          -0.0021 -0.0005  0.7986
# 24           0.0007 -0.0005  0.1277
# 25           0.0061 -0.0003  0.8066
# 26          -0.0072 -0.0002  1.0861
# 27           0.0031  0.0000  0.6977
# 28           0.0045 -0.0003  0.6938
# 29           0.0044 -0.0001  0.8863
# 30          -0.0050  0.0001  0.7730
# 31          -0.0025 -0.0010  1.1559
# 32          -0.0045 -0.0001  1.0488
# 33          -0.0099  0.0010  1.2306
# 34           0.0012 -0.0003  0.6116

# %%
long_df = f1_df[['Date','Ticker','Class','Sub_Class','pct_share_value','alpha','beta']].copy()
long_df= long_df[long_df['Class'] == 'Economically Sensitive']

long_df.reset_index(inplace=True, drop=True)
long_df = long_df.melt(id_vars=['Date','Ticker','Class','Sub_Class'])
long_df.head()
# Out:
#         Date Ticker                   Class              Sub_Class  \
# 0 2023-10-13  BLUEX  Economically Sensitive    Long/Short Equities
# 1 2023-10-13  BPLSX  Economically Sensitive    Long/Short Equities
# 2 2023-10-13   DFAR  Economically Sensitive  Publicly Traded REITs
# 3 2023-10-13   FREL  Economically Sensitive  Publicly Traded REITs
# 4 2023-10-13   FSMD  Economically Sensitive          U.S. Equities
#
#           variable   value
# 0  pct_share_value -0.0012
# 1  pct_share_value  0.0000
# 2  pct_share_value -0.0010
# 3  pct_share_value -0.0015
# 4  pct_share_value -0.0072

# %%
#long_df = f1_df['pct_share_value','alpha','beta'].copy()
#long_df.reset_index(inplace=True)
#long_df = long_df.melt(id_vars=['Date','Ticker'])


# Graph
#fig, ax = plt.subplots(figsize=(14,10))
g = sns.FacetGrid(long_df, col='variable', row = 'Sub_Class', hue='variable',
                  height=3, aspect=2, sharex=False, sharey=False)

g.set_titles(col_template="{col_name}", row_template="{row_name}")
g.tick_params(axis='x', labelrotation=90) 
g.tight_layout()
g.map_dataframe(sns.barplot, y="Ticker", x="value")

plt.show()

# %%
merge_df
# Out:
#           Date Ticker   Price                    Class  \
# 0   2023-09-11  ALTVX  9.4000  Interest Rate Sensitive
# 1   2023-09-12  ALTVX  9.3900  Interest Rate Sensitive
# 2   2023-09-13  ALTVX  9.3900  Interest Rate Sensitive
# 3   2023-09-14  ALTVX  9.3800  Interest Rate Sensitive
# 4   2023-09-15  ALTVX  9.3800  Interest Rate Sensitive
# ..         ...    ...     ...                      ...
# 870 2023-10-09   VTEB 47.8100  Interest Rate Sensitive
# 871 2023-10-10   VTEB 47.8600  Interest Rate Sensitive
# 872 2023-10-11   VTEB 48.2100  Interest Rate Sensitive
# 873 2023-10-12   VTEB 48.1000  Interest Rate Sensitive
# 874 2023-10-13   VTEB 48.1600  Interest Rate Sensitive
#
#                              Sub_Class       Shares    share_value  \
# 0    Very-High-Quality Municipal Bonds 106,383.0000 1,000,000.1594
# 1    Very-High-Quality Municipal Bonds 106,383.0000   998,936.4065
# 2    Very-High-Quality Municipal Bonds 106,383.0000   998,936.4065
# 3    Very-High-Quality Municipal Bonds 106,383.0000   997,872.5522
# 4    Very-High-Quality Municipal Bonds 106,383.0000   997,872.5522
# ..                                 ...          ...            ...
# 870  Very-High-Quality Municipal Bonds  20,333.0000   972,120.7579
# 871  Very-High-Quality Municipal Bonds  20,333.0000   973,137.3924
# 872  Very-High-Quality Municipal Bonds  20,333.0000   980,253.9114
# 873  Very-High-Quality Municipal Bonds  20,333.0000   978,017.2690
# 874  Very-High-Quality Municipal Bonds  20,333.0000   979,237.2769
#
#      pct_share_value
# 0                NaN
# 1            -0.0011
# 2             0.0000
# 3            -0.0011
# 4             0.0000
# ..               ...
# 870           0.0061
# 871           0.0010
# 872           0.0073
# 873          -0.0023
# 874           0.0012
#
# [875 rows x 8 columns]

# %%
set(merge_df['Sub_Class'])
# Out:
# {'Cash',
#  'Emerging Market Equities',
#  'International Equities',
#  'Long/Short Equities',
#  'Private Equity',
#  'Publicly Traded REITs',
#  'U.S. Equities',
#  'U.S. Government Bonds',
#  'Very-High-Quality Corporate Bonds',
#  'Very-High-Quality Municipal Bonds'}

# %%
m_df = merge_df[merge_df['Sub_Class'] == 'U.S. Equities']
#m_df = merge_df[(merge_df['Class'] == 'Economically Sensitive') & (merge_df['Ticker'] == 'BLUEX')]
m_df
# Out:
#           Date Ticker   Price                   Class      Sub_Class  \
# 150 2023-09-11   FSMD 33.2600  Economically Sensitive  U.S. Equities
# 151 2023-09-12   FSMD 33.2000  Economically Sensitive  U.S. Equities
# 152 2023-09-13   FSMD 33.0300  Economically Sensitive  U.S. Equities
# 153 2023-09-14   FSMD 33.4400  Economically Sensitive  U.S. Equities
# 154 2023-09-15   FSMD 33.0000  Economically Sensitive  U.S. Equities
# ..         ...    ...     ...                     ...            ...
# 845 2023-10-09   VONG 70.2100  Economically Sensitive  U.S. Equities
# 846 2023-10-10   VONG 70.5100  Economically Sensitive  U.S. Equities
# 847 2023-10-11   VONG 71.0900  Economically Sensitive  U.S. Equities
# 848 2023-10-12   VONG 70.7600  Economically Sensitive  U.S. Equities
# 849 2023-10-13   VONG 70.0600  Economically Sensitive  U.S. Equities
#
#           Shares    share_value  pct_share_value
# 150 120,705.0000 4,014,648.0974              NaN
# 151 120,705.0000 4,007,406.0921          -0.0018
# 152 120,705.0000 3,986,886.0027          -0.0051
# 153 120,705.0000 4,036,375.0342           0.0124
# 154 120,705.0000 3,983,265.0000          -0.0132
# ..           ...            ...              ...
# 845  41,501.0000 2,913,785.1720           0.0050
# 846  41,501.0000 2,926,235.5987           0.0043
# 847  41,501.0000 2,950,305.9380           0.0082
# 848  41,501.0000 2,936,610.8487          -0.0046
# 849  41,501.0000 2,907,559.9587          -0.0099
#
# [175 rows x 8 columns]

# %%
# Graph
fig, ax = plt.subplots(figsize=(16,8))
plt.ticklabel_format(style='plain', axis='y')

ax.set_ylim(-.05, 0.05)
ax.tick_params(axis='x', labelrotation=90) 
xticks = xticks = m_df['Date'].tolist()
ax.set_xticklabels([pd.to_datetime(tm, unit='d').strftime('%b-%d') for tm in xticks])

# Plot
sns.set_style("white")
g = sns.lineplot(data=m_df, x="Date", y="pct_share_value", hue='Ticker')
#g = sns.lineplot(data=m1_df, x="Date", y="bench", color='red', linestyle="dashed")
#ax = sns.lineplot(x=x, y=y, linestyle="dashed")
g.set_yticklabels(['{:,.1f}'.format(x) + ' %' for x in g.get_yticks() * 100])

plt.axhline(y=0, linestyle="dashed", color='lightgray')

ax.set(title='Portfolio Performance (vs SPY)');

# %%
#FSMD
1000000 / 31.6200
# Out:
# 31625.553447185324

# %%
# IMCB
1000000 / 59.2600
# Out:
# 16874.789065136687

# %%
1000000
# Out:
# 1000000
